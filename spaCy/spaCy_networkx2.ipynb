# %% [markdown]
# # spaCy and networkx その２
#
# Date: 2023/12/20

# %%
import re

# %%
with open('../data/pg35041_.txt') as f:
    text_ = f.read()

text = re.sub(r'_*\(\d+\)|_', '', text_)
print(text[:3000])
# Out:
# CHAPTER I. THE FAMILY OF BACH
#
#
# If there is such a thing as inherited aptitude for art it certainly showed
# itself in the family of Bach. For six successive generations scarcely two
# or three of its members are found whom nature had not endowed with
# remarkable musical talent, and who did not make music their
# profession.
#
# Veit Bach, ancestor of this famous family, gained a livelihood as a
# baker at Pressburg in Hungary.  When the religious troubles of the
# sixteenth century broke out he was driven to seek another place of abode,
# and having got together as much of his small property as he could, retired
# with it to Thuringia, hoping to find peace and security there.  He settled
# at Wechmar, a village near Gotha, where he continued to ply his trade
# as a baker and miller. In his leisure hours he was wont to amuse
# himself with the lute, playing it amid the noise and clatter of the
# mill.  His taste for music descended to his two sons and their
# children, and in time the Bachs grew to be a very numerous family of
# professional musicians, Cantors, Organists, and Town Musicians,
# throughout  Thuringia.
#
# Not all the Bachs, however, were great musicians. But every generation
# boasted some of them who were more than usually distinguished.  In the
# first quarter of the seventeenth century three of Veit Bach's
# grandchildren showed such exceptional talent that the Count of
# Schwarzburg-Arnstadt thought it worth while to send them at his expense to
# Italy, then the chief school of music, to perfect themselves in the
# art.
#
# We do not know whether they rewarded the expectations of their patron, for
# none of their works has survived. The fourth generation of the family
# produced musicians of exceptional distinction, and several of their
# compositions, thanks to Johann Sebastian Bach's regard for them, have come
# down to us. The most notable of these Bachs are:
#
#    1. Johann Christoph Bach, Court and Town Organist at Eisenach. He
#       was particularly happy in his beautiful melodies and in setting
#       words to music. In the Archives of the Bachs, which was in
#       Carl Philipp Emmanuel's possession at Hamburg, there is a Motet by
#       Johann Christoph in which he boldly uses the augmented sixth, a
#       proceeding considered extremely daring in his day. He was also
#       an uncommon master of harmony, as may be inferred from a Cantata
#       composed by him for Michaelmas, to the words "Es erhub sich ein
#       Streit," etc., which has twenty-two obbligato parts in correct
#       harmony. Yet another proof of his rare skill is in the alleged
#       fact that he never played the Organ or Clavier in less than five
#       parts. Carl Philipp Emmanuel had a particularly warm regard for
#       him. I remember the old man playing some of his compositions to
#       me on the Clavier at Hamburg, and how quizzically he looked at me
#       when one of these daring passages occurred.
#    2. Johann Michael Bach, Organist and Town Clerk at Gehren. He was
#       the younger brother of Johann Christoph,

# %%
cleaned_names =['Anna Magdalena',
 'Bach',
 'Beethoven',
 'Böhm',
 'Carl Philipp',
 'Carl Philipp Emmanuel',
 'Caspar Kerl',
 'Charles III',
 'Charles of Sicily',
 'Christopher Weigel',
 'Count Kaiserling',
 'Couperin',
 'Duke Christian of Weissenfels',
 'Duke Ernst',
 'Elias Gottlieb Haussmann',
 'Emmanuel Bach',
 'Fischer',
 'Frederick II',
 'Frescobaldi',
 'Friedemann',
 'Friedrich Müller',
 'Fritz',
 'Fritz Volbach',
 'Froberger',
 'Görner',
 'Handel',
 'Hasse',
 'Haussmann',
 'Hence Bach',
 'Herein Bach',
 'J. C. Gottsched',
 'Johann Ambrosius',
 'Johann Abraham Birnbaum',
 'Johann Adam Reinken',
 'Johann Ambrosius Bach',
 'Johann Bernhard Bach',
 'Johann Christian Hoffmann',
 'Johann Christoph',
 'Johann Christoph Bach',
 "Johann Christoph Friedrich's",
 'Johann G. Schübler',
 'Johann Gottlieb Görner',
 'Johann Heinrich Ernesti',
 'Johann Matthias Gesner',
 'Johann Michael Bach',
 'Johann Sebastian',
 'Johann Sebastian Bach',
 'Kerl',
 'Maria Amalia',
 'Marianne von Ziegler',
 'Müller',
 'Nicolas',
 'Pachelbel',
 'Paul Wagner',
 'Peters',
 'Philipp Telemann',
 'Regine Susanna',
 'Reinhard Keiser',
 'Sebastian Bach',
 'Veit Bach',
 'Vereinigte Zwietracht',
 'Vierstimmige Choralgesänge',
 'Vivaldi',
 'Vom Himmel',
 'Wahre Grundsätze',
 'Wasserflüssen Babylon',
 'Wilhelm Friedemann']

# %%
import spacy
from spacy.matcher import PhraseMatcher

# %%
nlp = spacy.load('en_core_web_trf')
doc = nlp(text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'

# %%
#[sent.text.strip() for sent in doc.sents]
sents = [sent.text.strip().replace('\n', ' ') for sent in doc.sents]
sents[300:310]
# Out:
# ['The Council retaliated by accusing Bach of neglecting his singing classes, absenting himself without leave, and of other irregularities.',
#  '',
#  'He was declared to be "incorrigible" and it was resolved (August 2, 1730) to sequestrate the Cantor\'s income, in other words, to withhold from him the perquisites to which he was entitled for the conduct of the Church services.',
#  'Bach was not deterred from offering, three weeks later (August 23, 1730), a "sketch of what constitutes well-appointed Church music, with a few impartial reflections on its present state of decay" in Leipzig.',
#  'The document reveals the conditions amid which Bach worked.',
#  '',
#  "Its representations may be summarised:  The foundation scholars of St. Thomas' are of four classes: Trebles, Altos, Tenors, Basses.",
#  'A choir needs from four to eight "concertists" ( solo singers) and at least two "ripienists" to each chorus part, i.e. a minimum of twelve voices.',
#  "The foundation scholars number fifty-five, by whom the choirs of the four Churches, St. Thomas', St. Nicolas', St. Peter's, and the New Church are provided.",
#  'For the instrumental accompaniments at least twenty players are required: viz., 2 or 3 first Violins, 2 or 3 second Violins, 4 Violas, 2 Violoncelli, 1 Contrabasso, 2 or more Flutes, 2 or 3 Oboi, 1 or 2 Fagotti, 3 Trombe, 1 Timpani.']

# %%
REPLACE = {'Bach': 'Johann Sebastian Bach',
           'Johann Sebastian': 'Johann Sebastian Bach',
           'Sebastian Bach': 'Johann Sebastian Bach',
           'Carl Philipp': 'Carl Philipp Emanuel Bach',
           'Carl Philipp Emanuel': 'Carl Philipp Emanuel Bach',
           'Carl Philipp Emmanuel': 'Carl Philipp Emanuel Bach', 
           'Emmanuel Bach': 'Carl Philipp Emanuel Bach',            
           'Wilhelm Friedemann': 'Wilhelm Friedemann Bach',
           'Friedemann': 'Wilhelm Friedemann Bach',
           'Johann Christoph': 'Johann Christoph Bach',
           'Anna Magdalena': 'Anna Magdalena Bach',
           'Regine Susanna': 'Regine Susanna Bach',
           'Johann Ambrosius': 'Johann Ambrosius Bach'
          }

def align_name(name):
    name = name.replace("'s", "")
    if name in REPLACE:
        return REPLACE[name]
    else:
        return name

# %%
# 英文からドイツ人名抽出だからNERかけないでPhraseMatcherでも行ける。
# 本来はNERかけるべきだが、ここでは省略。
from itertools import combinations

matcher = PhraseMatcher(nlp.vocab)
patterns = [nlp.make_doc(name) for name in cleaned_names]
matcher.add('names', patterns)

comb = []
for doc in nlp.pipe(sents):
    #print(f'---{doc.text}')
    matches = matcher(doc)
    if len(matches) >= 2:
        matched = set()
        for match_id, start, end in matches:
            span = doc[start:end]
            name = align_name(span.text)
            matched.add(name)
        if len(matched) >= 2:
            comb.extend(combinations(matched, 2))

comb
# Out:
# [('Veit Bach', 'Johann Sebastian Bach'),
#  ('Veit Bach', 'Johann Sebastian Bach'),
#  ('Johann Christoph Bach', 'Johann Sebastian Bach'),
#  ('Johann Christoph Bach', 'Carl Philipp Emanuel Bach'),
#  ('Johann Michael Bach', 'Johann Sebastian Bach'),
#  ('Johann Bernhard Bach', 'Johann Sebastian Bach'),
#  ('Johann Ambrosius Bach', 'Johann Sebastian Bach'),
#  ('Johann Ambrosius Bach', 'Johann Christoph Bach'),
#  ('Froberger', 'Böhm'),
#  ('Froberger', 'Fischer'),
#  ('Froberger', 'Kerl'),
#  ('Froberger', 'Pachelbel'),
#  ('Froberger', 'Caspar Kerl'),
#  ('Böhm', 'Fischer'),
#  ('Böhm', 'Kerl'),
#  ('Böhm', 'Pachelbel'),
#  ('Böhm', 'Caspar Kerl'),
#  ('Fischer', 'Kerl'),
#  ('Fischer', 'Pachelbel'),
#  ('Fischer', 'Caspar Kerl'),
#  ('Kerl', 'Pachelbel'),
#  ('Kerl', 'Caspar Kerl'),
#  ('Pachelbel', 'Caspar Kerl'),
#  ('Johann Christoph Bach', 'Johann Sebastian Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Wilhelm Friedemann Bach', 'Carl Philipp Emanuel Bach'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Görner', 'Nicolas'),
#  ('Görner', 'Johann Gottlieb Görner'),
#  ('Nicolas', 'Johann Gottlieb Görner'),
#  ('Nicolas', 'Johann Sebastian Bach'),
#  ('Johann Sebastian Bach', 'Nicolas'),
#  ('Paul Wagner', 'Johann Sebastian Bach'),
#  ('Anna Magdalena Bach', 'Johann Sebastian Bach'),
#  ('Anna Magdalena Bach', 'Johann Sebastian Bach'),
#  ('Görner', 'Johann Sebastian Bach'),
#  ('Friedrich Müller', 'Müller'),
#  ('Vereinigte Zwietracht', 'Johann Sebastian Bach'),
#  ('Maria Amalia', 'Charles III'),
#  ('Maria Amalia', 'Johann Sebastian Bach'),
#  ('Maria Amalia', 'Charles of Sicily'),
#  ('Charles III', 'Johann Sebastian Bach'),
#  ('Charles III', 'Charles of Sicily'),
#  ('Johann Sebastian Bach', 'Charles of Sicily'),
#  ('J. C. Gottsched', 'Johann Abraham Birnbaum'),
#  ('J. C. Gottsched', 'Johann Christian Hoffmann'),
#  ('J. C. Gottsched', 'Marianne von Ziegler'),
#  ('J. C. Gottsched', 'Johann Sebastian Bach'),
#  ('Johann Abraham Birnbaum', 'Johann Christian Hoffmann'),
#  ('Johann Abraham Birnbaum', 'Marianne von Ziegler'),
#  ('Johann Abraham Birnbaum', 'Johann Sebastian Bach'),
#  ('Johann Christian Hoffmann', 'Marianne von Ziegler'),
#  ('Johann Christian Hoffmann', 'Johann Sebastian Bach'),
#  ('Marianne von Ziegler', 'Johann Sebastian Bach'),
#  ('Peters', 'Carl Philipp Emanuel Bach'),
#  ('Haussmann', 'Elias Gottlieb Haussmann'),
#  ('Fritz Volbach', 'Fritz'),
#  ('Wilhelm Friedemann Bach', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Regine Susanna Bach'),
#  ('Johann Christoph Friedrich', 'Johann Christoph Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Couperin', 'Johann Sebastian Bach'),
#  ('Couperin', 'Johann Sebastian Bach'),
#  ('Couperin', 'Johann Sebastian Bach'),
#  ('Couperin', 'Johann Sebastian Bach'),
#  ('Couperin', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Couperin', 'Johann Sebastian Bach'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Froberger', 'Böhm'),
#  ('Froberger', 'Kerl'),
#  ('Froberger', 'Fischer'),
#  ('Froberger', 'Frescobaldi'),
#  ('Froberger', 'Pachelbel'),
#  ('Böhm', 'Kerl'),
#  ('Böhm', 'Fischer'),
#  ('Böhm', 'Frescobaldi'),
#  ('Böhm', 'Pachelbel'),
#  ('Kerl', 'Fischer'),
#  ('Kerl', 'Frescobaldi'),
#  ('Kerl', 'Pachelbel'),
#  ('Fischer', 'Frescobaldi'),
#  ('Fischer', 'Pachelbel'),
#  ('Frescobaldi', 'Pachelbel'),
#  ('Johann Sebastian Bach', 'Herein Bach'),
#  ('Handel', 'Reinhard Keiser'),
#  ('Johann Sebastian Bach', 'Herein Bach'),
#  ('Vierstimmige Choralgesänge', 'Johann Sebastian Bach'),
#  ('Vierstimmige Choralgesänge', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Handel', 'Johann Sebastian Bach'),
#  ('Johann Sebastian Bach', 'Fritz'),
#  ('Wilhelm Friedemann Bach', 'Carl Philipp Emanuel Bach'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Herein Bach'),
#  ('Hasse', 'Handel'),
#  ('Hasse', 'Reinhard Keiser'),
#  ('Handel', 'Reinhard Keiser'),
#  ('Wilhelm Friedemann Bach', 'Handel'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Handel', 'Johann Sebastian Bach'),
#  ('Handel', 'Johann Sebastian Bach'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Duke Ernst', 'Duke Christian of Weissenfels'),
#  ('Vom Himmel', 'Johann Sebastian Bach'),
#  ('Johann Sebastian Bach', 'Count Kaiserling'),
#  ('Johann Sebastian Bach', 'Carl Philipp Emanuel Bach'),
#  ('Johann Sebastian Bach', 'Pachelbel'),
#  ('Wilhelm Friedemann Bach', 'Johann Sebastian Bach'),
#  ('Hence Bach', 'Johann Sebastian Bach')]

# %%
import pandas as pd
relationships_df = pd.DataFrame(comb, columns=['source', 'target'])
relationships_df
# Out:
#                       source                     target
# 0                  Veit Bach      Johann Sebastian Bach
# 1                  Veit Bach      Johann Sebastian Bach
# 2      Johann Christoph Bach      Johann Sebastian Bach
# 3      Johann Christoph Bach  Carl Philipp Emanuel Bach
# 4        Johann Michael Bach      Johann Sebastian Bach
# ..                       ...                        ...
# 107    Johann Sebastian Bach           Count Kaiserling
# 108    Johann Sebastian Bach  Carl Philipp Emanuel Bach
# 109    Johann Sebastian Bach                  Pachelbel
# 110  Wilhelm Friedemann Bach      Johann Sebastian Bach
# 111               Hence Bach      Johann Sebastian Bach
#
# [112 rows x 2 columns]

# %%
all_characters = pd.concat([relationships_df['source'], relationships_df['target']]).unique()
all_characters
# Out:
# array(['Veit Bach', 'Johann Christoph Bach', 'Johann Michael Bach',
#        'Johann Bernhard Bach', 'Johann Ambrosius Bach', 'Froberger',
#        'Böhm', 'Fischer', 'Kerl', 'Pachelbel', 'Johann Sebastian Bach',
#        'Wilhelm Friedemann Bach', 'Görner', 'Nicolas', 'Paul Wagner',
#        'Anna Magdalena Bach', 'Friedrich Müller', 'Vereinigte Zwietracht',
#        'Maria Amalia', 'Charles III', 'J. C. Gottsched',
#        'Johann Abraham Birnbaum', 'Johann Christian Hoffmann',
#        'Marianne von Ziegler', 'Peters', 'Haussmann', 'Fritz Volbach',
#        'Johann Christoph Friedrich', 'Couperin', 'Frescobaldi', 'Handel',
#        'Vierstimmige Choralgesänge', 'Hasse', 'Duke Ernst', 'Vom Himmel',
#        'Hence Bach', 'Carl Philipp Emanuel Bach', 'Caspar Kerl',
#        'Johann Gottlieb Görner', 'Müller', 'Charles of Sicily',
#        'Elias Gottlieb Haussmann', 'Fritz', 'Regine Susanna Bach',
#        'Herein Bach', 'Reinhard Keiser', 'Duke Christian of Weissenfels',
#        'Count Kaiserling'], dtype=object)

# %%
relationships_df['weight'] = 1
relationships_df_ = relationships_df.groupby(['source', 'target'], sort=False, as_index=False).sum()
relationships_df_.head()
# Out:
#                   source                     target  weight
# 0              Veit Bach      Johann Sebastian Bach       2
# 1  Johann Christoph Bach      Johann Sebastian Bach       2
# 2  Johann Christoph Bach  Carl Philipp Emanuel Bach       1
# 3    Johann Michael Bach      Johann Sebastian Bach       1
# 4   Johann Bernhard Bach      Johann Sebastian Bach       1

# %%
import networkx as nx
G = nx.from_pandas_edgelist(relationships_df_,
                            source = 'source',
                            target = 'target',
                            edge_attr = 'weight',
                            create_using=nx.Graph())

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, ax=ax, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos)
plt.show()

# %%
from pyvis.network import Network
net = Network(notebook=True, width='1000px', height='700px', bgcolor='#222222', font_color='white', cdn_resources='in_line')

node_degree = dict(G.degree)
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G, edge_scaling=True, show_edge_weights=True)
net.show('bach.html')
# Out:
# bach.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="bach.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
degree_dict = nx.degree_centrality(G)
degree_dict
# Out:
# {'Veit Bach': 0.02127659574468085,
#  'Johann Sebastian Bach': 0.6170212765957447,
#  'Johann Christoph Bach': 0.0851063829787234,
#  'Carl Philipp Emanuel Bach': 0.1276595744680851,
#  'Johann Michael Bach': 0.02127659574468085,
#  'Johann Bernhard Bach': 0.02127659574468085,
#  'Johann Ambrosius Bach': 0.0425531914893617,
#  'Froberger': 0.1276595744680851,
#  'Böhm': 0.1276595744680851,
#  'Fischer': 0.1276595744680851,
#  'Kerl': 0.1276595744680851,
#  'Pachelbel': 0.14893617021276595,
#  'Caspar Kerl': 0.10638297872340426,
#  'Wilhelm Friedemann Bach': 0.06382978723404255,
#  'Görner': 0.06382978723404255,
#  'Nicolas': 0.06382978723404255,
#  'Johann Gottlieb Görner': 0.0425531914893617,
#  'Paul Wagner': 0.02127659574468085,
#  'Anna Magdalena Bach': 0.02127659574468085,
#  'Friedrich Müller': 0.02127659574468085,
#  'Müller': 0.02127659574468085,
#  'Vereinigte Zwietracht': 0.02127659574468085,
#  'Maria Amalia': 0.06382978723404255,
#  'Charles III': 0.06382978723404255,
#  'Charles of Sicily': 0.06382978723404255,
#  'J. C. Gottsched': 0.0851063829787234,
#  'Johann Abraham Birnbaum': 0.0851063829787234,
#  'Johann Christian Hoffmann': 0.0851063829787234,
#  'Marianne von Ziegler': 0.0851063829787234,
#  'Peters': 0.02127659574468085,
#  'Haussmann': 0.02127659574468085,
#  'Elias Gottlieb Haussmann': 0.02127659574468085,
#  'Fritz Volbach': 0.02127659574468085,
#  'Fritz': 0.0425531914893617,
#  'Regine Susanna Bach': 0.02127659574468085,
#  'Johann Christoph Friedrich': 0.02127659574468085,
#  'Couperin': 0.0425531914893617,
#  'Frescobaldi': 0.10638297872340426,
#  'Herein Bach': 0.02127659574468085,
#  'Handel': 0.0851063829787234,
#  'Reinhard Keiser': 0.0425531914893617,
#  'Vierstimmige Choralgesänge': 0.0425531914893617,
#  'Hasse': 0.0425531914893617,
#  'Duke Ernst': 0.02127659574468085,
#  'Duke Christian of Weissenfels': 0.02127659574468085,
#  'Vom Himmel': 0.02127659574468085,
#  'Count Kaiserling': 0.02127659574468085,
#  'Hence Bach': 0.02127659574468085}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
degree_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %%
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
betweenness_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %%
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
closeness_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %%
from community import community_louvain

communities = community_louvain.best_partition(G)

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
com_net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show_buttons(filter_=['physics'])
com_net.show("bach_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# bach_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="bach_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
