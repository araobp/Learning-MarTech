# %% [markdown]
# # spaCy and networkx
#
# Date: 2023/11/24-
#
# Reference: https://youtu.be/fAHkJ_Dhr50
#
# ドイツに住んでいた頃、バッハの音楽を聴きながら生活したので、バッハの本を選んだ。
#
# Free book "Johann Sebastian Bach: His Life, Art, and Work" from Project Gutenberg: https://www.gutenberg.org/ebooks/35041

# %%
import re
#Test
#re.sub(r'_*\(\d+\)', '', '_(123)')

# %%
with open('data/pg35041_.txt') as f:
    text_ = f.read()

text = re.sub(r'_*\(\d+\)', '', text_)
print(text[:3000])
# Out:
# CHAPTER I. THE FAMILY OF BACH
#
#
# If there is such a thing as inherited aptitude for art it certainly showed
# itself in the family of Bach. For six successive generations scarcely two
# or three of its members are found whom nature had not endowed with
# remarkable musical talent, and who did not make music their
# profession.
#
# Veit Bach, ancestor of this famous family, gained a livelihood as a
# baker at Pressburg in Hungary.  When the religious troubles of the
# sixteenth century broke out he was driven to seek another place of abode,
# and having got together as much of his small property as he could, retired
# with it to Thuringia, hoping to find peace and security there.  He settled
# at Wechmar, a village near Gotha, where he continued to ply his trade
# as a baker and miller. In his leisure hours he was wont to amuse
# himself with the lute, playing it amid the noise and clatter of the
# mill.  His taste for music descended to his two sons and their
# children, and in time the Bachs grew to be a very numerous family of
# professional musicians, Cantors, Organists, and Town Musicians,
# throughout  Thuringia.
#
# Not all the Bachs, however, were great musicians. But every generation
# boasted some of them who were more than usually distinguished.  In the
# first quarter of the seventeenth century three of Veit Bach's
# grandchildren showed such exceptional talent that the Count of
# Schwarzburg-Arnstadt thought it worth while to send them at his expense to
# Italy, then the chief school of music, to perfect themselves in the
# art.
#
# We do not know whether they rewarded the expectations of their patron, for
# none of their works has survived. The fourth generation of the family
# produced musicians of exceptional distinction, and several of their
# compositions, thanks to Johann Sebastian Bach's regard for them, have come
# down to us. The most notable of these Bachs are:
#
#    1. Johann Christoph Bach, Court and Town Organist at Eisenach. He
#       was particularly happy in his beautiful melodies and in setting
#       words to music. In the _Archives of the Bachs, which was in
#       Carl Philipp Emmanuel's possession at Hamburg, there is a Motet by
#       Johann Christoph in which he boldly uses the augmented sixth, a
#       proceeding considered extremely daring in his day. He was also
#       an uncommon master of harmony, as may be inferred from a Cantata
#       composed by him for Michaelmas, to the words "Es erhub sich ein
#       Streit," etc., which has twenty-two obbligato parts in correct
#       harmony. Yet another proof of his rare skill is in the alleged
#       fact that he never played the Organ or Clavier in less than five
#       parts. Carl Philipp Emmanuel had a particularly warm regard for
#       him. I remember the old man playing some of his compositions to
#       me on the Clavier at Hamburg, and how quizzically he looked at me
#       when one of these daring passages occurred.
#    2. Johann Michael Bach, Organist and Town Clerk at Gehren. He was
#       the younger brother of Johann Christoph

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.12)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# %%
displacy.render(doc[3000:6000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">similar manner
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     some years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  before and had</br>had his work engraved, showing that he thought highly of it.  His praise</br>therefore was particularly flattering to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br></br>On the death of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kuhnau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1723
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was appointed Director of Music</br>and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cantor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Thomas' School, Leipzig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a position which he</br>occupied until his death.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prince Leopold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anhalt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Cöthen had great</br>regard for him and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  left his service with regret. But he saw the</br>finger of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Providence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in the event; for the Prince died shortly</br>afterwards. The loss of his patron affected him deeply, and moved him</br>to compose a funeral Cantata containing remarkably fine double choruses</br>which he himself conducted at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cöthen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . While he was at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Thomas'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  he</br>was appointed honorary Kapellmeister to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Duke of Weissenfels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and,</br>in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the following year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , received the title of Court
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Composer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to the</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     King-Elector
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Saxony. The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  compliments are not of great</br>consequence, and the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  was to some degree corollary to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's</br>position as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cantor of St. Thomas' School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carl Philipp Emmanuel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,

# %%
characters = set()
for ent in doc.ents:
    if ent.label_ == 'PERSON':
        characters.add(ent.text)
characters
# Out:
# {'Alto',
#  'Anna Magdalena',
#  'Arias',
#  'Arnstadt',
#  'Aus',
#  'BACH',
#  'Bach',
#  'Bachs',
#  'Balthasar Schmidt',
#  'Bass',
#  'Beethoven',
#  'Brunswick',
#  'Böhm',
#  'CHAPTER V. BACH',
#  'Canon',
#  'Cantata',
#  'Cantatas',
#  'Carl Philipp',
#  'Carl Philipp Emmanuel',
#  "Carl Philipp Emmanuel's",
#  "Carl Philipp's",
#  'Caspar Kerl',
#  'Charles III',
#  'Charles of Sicily',
#  'Chori',
#  'Chorus',
#  'Christopher Weigel',
#  'Chromatic Fantasia',
#  'Clavicembalo',
#  'Clavier',
#  'Clavierübung',
#  'Composer',
#  'Concertmeister',
#  'Concertos',
#  'Consequently Couperin',
#  'Continuo',
#  'Count Kaiserling',
#  'Couperin',
#  'Creed',
#  'Der',
#  'Der Geist',
#  'Die Freude',
#  'Die Kunst',
#  'Divided Harmony',
#  'Duet',
#  'Duke Christian of Weissenfels',
#  'Duke Ernst',
#  'Einige',
#  'Elias Gottlieb Haussmann',
#  "Emmanuel Bach's",
#  'English Suites',
#  'Ernesti',
#  'Essay',
#  'Fantasia',
#  'Fifteen Two',
#  'Fischer',
#  'Frederick II',
#  'Frescobaldi',
#  'Friedemann',
#  "Friedrich Müller's",
#  'Fritz',
#  'Fritz Volbach',
#  'Froberger',
#  'Fuge',
#  'Fugue',
#  'Fürchte',
#  'Gehren',
#  'Gesner',
#  'Gigue',
#  'Gloria',
#  'Goldberg',
#  'Gospel',
#  'Gott',
#  'Gottes Sohn',
#  'Gottlieb Kortte',
#  'Görner',
#  'Handel',
#  'Harmonie',
#  'Harpsichord',
#  'Harpsichord Knights',
#  'Hasse',
#  'Haussmann',
#  "Hence Bach's",
#  "Herein\nBach's",
#  'Herein Bach',
#  'Herr Jesu Christ',
#  'Hitherto',
#  'Hoffmeister',
#  'Hurlebusch',
#  'Hymn',
#  'Hymn-book',
#  'J. C. Gottsched',
#  'Jesu',
#  'Johann',
#  'Johann\nAmbrosius',
#  'Johann Abraham Birnbaum',
#  'Johann Adam\nReinken',
#  'Johann Ambrosius Bach',
#  'Johann Bernhard Bach',
#  'Johann Christian Hoffmann',
#  'Johann Christoph',
#  'Johann Christoph Bach',
#  "Johann Christoph Friedrich's",
#  'Johann G. Schübler',
#  'Johann Gottlieb Görner',
#  'Johann Heinrich Ernesti',
#  'Johann Matthias Gesner',
#  'Johann Michael Bach',
#  'Johann Sebastian',
#  'Johann Sebastian Bach',
#  "Johann Sebastian Bach's",
#  'KREBS',
#  'Kapellmeister',
#  'Kerl',
#  'Komm',
#  'Kunstwerk',
#  'Kyrie',
#  'Kühnel',
#  "L'Art de toucher\n",
#  'Mach',
#  'Magnificat',
#  'Mainz',
#  'Majesty',
#  'Maria Amalia',
#  'Marianne von Ziegler',
#  'Melody',
#  'Michaelmas',
#  'Minuet',
#  'Musices',
#  'Musici Lipsiensis',
#  'Musik von Sebastian',
#  'Musikalisches Opfer',
#  'Mühlhausen',
#  'Müller',
#  'Nay',
#  'Nicolas',
#  'Nimm',
#  'Nöthen',
#  'Ohrdruf',
#  'Opus I. Published',
#  'Organ',
#  'Organ Prelude',
#  'PERSONAL CHARACTERISTICS',
#  'Pachelbel',
#  'Paul Wagner',
#  'Peters',
#  'Philipp Telemann',
#  'Pianoforte',
#  'Preise dein Glücke',
#  'Prince Leopold',
#  'Quartet',
#  'Refusal',
#  'Regine Susanna',
#  'Reinhard Keiser',
#  'Reinken',
#  'Reinken of Hamburg',
#  'Roman Law',
#  'Saloon',
#  'Satzes',
#  'Saxony',
#  'Schleicht',
#  'Sebastian Bach',
#  'Sechs Choräle',
#  'Sermon',
#  'Several Concertos',
#  'Several Sonatas',
#  'Singet dem Herrn',
#  'Six Sonatas',
#  'Solo',
#  'Solo Suites',
#  'Sonatas',
#  'Sorge',
#  'Spiritus Sancti',
#  "St. Peter's",
#  'Sterne',
#  'Strungk',
#  'Stunden',
#  'Tenor',
#  'The Violoncello Solos',
#  'Thomana',
#  'Veit Bach',
#  'Vereinigte Zwietracht',
#  'Vierstimmige\nChoralgesänge',
#  'Viol da Gamba',
#  'Violin',
#  'Violin Concertos',
#  'Vivaldi',
#  'Vom Himmel',
#  'WILHELM FRIEDEMANN BACH',
#  'Wahre Grundsätze',
#  'Wasserflüssen Babylon',
#  'Weimar',
#  'Wellen',
#  'Wenn',
#  'Wilhelm\nFriedemann',
#  'Wilhelm Friedemann',
#  'another Bach Cantata',
#  'deine',
#  'ich bin dei dir',
#  'nicht allen gefallen durch',
#  'obbligato pedal',
#  'vielen gefallen'}

# %%
cleaned_names ={'Alto',
 'Anna Magdalena',
 'Bach',
 'Beethoven',
 'Brunswick',
 'Böhm',
 'Carl Philipp',
 'Carl Philipp Emmanuel',
 'Caspar Kerl',
 'Charles III',
 'Charles of Sicily',
 'Christopher Weigel',
 'Count Kaiserling',
 'Couperin',
 'Duke Christian of Weissenfels',
 'Duke Ernst',
 'Elias Gottlieb Haussmann',
 'Emmanuel Bach',
 'Fischer',
 'Frederick II',
 'Frescobaldi',
 'Friedemann',
 'Friedrich Müller',
 'Fritz',
 'Fritz Volbach',
 'Froberger',
 'Görner',
 'Handel',
 'Hasse',
 'Haussmann',
 'Hence Bach',
 'Herein Bach',
 'J. C. Gottsched',
 'Johann Ambrosius',
 'Johann Abraham Birnbaum',
 'Johann Adam Reinken',
 'Johann Ambrosius Bach',
 'Johann Bernhard Bach',
 'Johann Christian Hoffmann',
 'Johann Christoph',
 'Johann Christoph Bach',
 "Johann Christoph Friedrich's",
 'Johann G. Schübler',
 'Johann Gottlieb Görner',
 'Johann Heinrich Ernesti',
 'Johann Matthias Gesner',
 'Johann Michael Bach',
 'Johann Sebastian',
 'Johann Sebastian Bach',
 'Kerl',
 'Maria Amalia',
 'Marianne von Ziegler',
 'Michaelmas',
 'Müller',
 'Nicolas',
 'Pachelbel',
 'Paul Wagner',
 'Peters',
 'Philipp Telemann',
 'Regine Susanna',
 'Reinhard Keiser',
 'Sebastian Bach',
 'Veit Bach',
 'Vereinigte Zwietracht',
 'Vierstimmige Choralgesänge',
 'Vivaldi',
 'Vom Himmel',
 'Wahre Grundsätze',
 'Wasserflüssen Babylon',
 'Wilhelm Friedemann',
 'another Bach Cantata'}

# %%
sent_entity_df = []

for sent in doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({'sentence': sent, 'entities': entity_list})

import pandas as pd

sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
sent_entity_df[500:550]
# Out:
#                                               sentence  \
# 500  (When, Wilhelm, Friedemann, \n, played, the, C...
# 501  (When, he, \n, played, the, Organ, he, inspire...
# 502        (On, the, one, he, was, \n, charming, .,  )
# 503  (On, the, other, he, was, solemn, ,, impressiv...
# 504  (So, also, was, his, father, ,, \n, and, to, a...
# 505  (Wilhelm, Friedemann, was, a, mere, child, to,...
# 506  (The, music, that, \n, extraordinary, man, wro...
# 507  (His, improvisation, was, even, \n, more, insp...
# 508     (What, is, \n, the, essence, of, this, art, ?)
# 509  (Let, me, ,, though, imperfectly, ,, attempt, ...
# 510  (When, we, compare, Bach, 's, Clavier, composi...
# 511  (Hence, we, conclude, that, a, good, organist,...
# 512  (Its, great, body, of, tone, renders, the, Org...
# 513  (Its, echoes, must, have, liberty, to, rise, a...
# 514  (What, is, played, upon, it, must, be, suited,...
# 515  (Occasionally, and, exceptionally, a, solo, st...
# 516  (But, the, proper, function, of, the, Organ, i...
# 517  (The, composer, therefore, must, \n, not, writ...
# 518  (What, \n, is, commonplace, and, trite, can, n...
# 519  (It, must, therefore, be, banished, from, the,...
# 520    (How, clearly, Bach, grasped, that, fact, !,  )
# 521  (Even, his, secular, music, disdained, \n, tri...
# 522  (Much, more, so, his, Organ, music, ,, in, whi...
# 523  (Of, the, means, by, which, Bach, attained, to...
# 524  (The, \n, remoteness, of, the, ecclesiastical,...
# 525  (Any, one, who, looks, at, Bach, 's, simple, f...
# 526  (But, no, one, can, \n, realise, how, the, Org...
# 527  (It, becomes, a, choir, of, four, or, five, pa...
# 528  (Compare, the, following, chords, in, divided,...
# 529  ([, Divided, Harmony, ,, Bach, treatment, ], \...
# 530  (We, realise, instantly, the, \n, effect, when...
# 531  (Bach, \n, always, played, the, Organ, so, ,, ...
# 532  (He, employed, it, not, only, to, sound, the, ...
# 533  (To, these, qualities, must, be, added, the, e...
# 534  (His, registration, frequently, astonished, \n...
# 535  (Bach, 's, peculiar, registration, was, based,...
# 536  (Very, early, in, his, \n, career, he, made, a...
# 537  (Nothing, escaped, his, notice, which, had, th...
# 538  (For, instance, ,, he, made, a, point, of, obs...
# 539  (The, \n, practised, ear, ,, which, enabled, h...
# 540  (When, he, was, at, Berlin, in, 1747, he, was,...
# 541  (He, took, in, its, good, and, bad, qualities,...
# 542  (He, was, shown, the, large, adjoining, Saloon...
# 543  (Merely, glancing, at, the, \n, roof, he, rema...
# 544  (The, Saloon, ,, in, \n, fact, ,, is, a, paral...
# 545  (If, a, person, puts, his, face, to, the, wall...
# 546  (The, effect, arises, from, the, span, of, the...
# 547  (These, and, similar, \n, observations, sugges...
# 548  (Bach, brought, the, methods, I, have, indicat...
# 549  (His, profound, knowledge, of, harmony, ,, unf...
#
#                                      entities
# 500             [Wilhelm Friedemann, Clavier]
# 501                                   [Organ]
# 502                                        []
# 503                                        []
# 504                                        []
# 505                      [Wilhelm Friedemann]
# 506                                   [Organ]
# 507                                        []
# 508                                        []
# 509                                        []
# 510                    [Bach, Clavier, Organ]
# 511                                        []
# 512                                   [Organ]
# 513                                        []
# 514                                        []
# 515                                        []
# 516                                   [Organ]
# 517                                        []
# 518                                        []
# 519                                   [Organ]
# 520                                    [Bach]
# 521                                        []
# 522                                   [Organ]
# 523                     [Bach, Organ, Church]
# 524                         [our twenty-four]
# 525                        [Bach, four, Hymn]
# 526                                   [Organ]
# 527                            [four or five]
# 528                                        []
# 529  [Divided Harmony, Bach, Divided Harmony]
# 530                                    [four]
# 531                                   [Organ]
# 532                                    [five]
# 533                             [Bach, Organ]
# 534                     [Organ, first, Organ]
# 535                             [Bach, Organ]
# 536                                   [Organ]
# 537                                        []
# 538                                        []
# 539                                        []
# 540              [Berlin, 1747, Opera, House]
# 541                                        []
# 542                                  [Saloon]
# 543                                        []
# 544                                  [Saloon]
# 545                                     [one]
# 546                                    [Bach]
# 547                                   [Organ]
# 548                            [Bach, Church]
# 549                                   [Organ]

# %%
def filter_entity(ent_list):
    return [ent for ent in ent_list if ent in cleaned_names]

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(filter_entity)

# %%
sent_entity_df[500:550]
# Out:
#                                               sentence  \
# 500  (When, Wilhelm, Friedemann, \n, played, the, C...
# 501  (When, he, \n, played, the, Organ, he, inspire...
# 502        (On, the, one, he, was, \n, charming, .,  )
# 503  (On, the, other, he, was, solemn, ,, impressiv...
# 504  (So, also, was, his, father, ,, \n, and, to, a...
# 505  (Wilhelm, Friedemann, was, a, mere, child, to,...
# 506  (The, music, that, \n, extraordinary, man, wro...
# 507  (His, improvisation, was, even, \n, more, insp...
# 508     (What, is, \n, the, essence, of, this, art, ?)
# 509  (Let, me, ,, though, imperfectly, ,, attempt, ...
# 510  (When, we, compare, Bach, 's, Clavier, composi...
# 511  (Hence, we, conclude, that, a, good, organist,...
# 512  (Its, great, body, of, tone, renders, the, Org...
# 513  (Its, echoes, must, have, liberty, to, rise, a...
# 514  (What, is, played, upon, it, must, be, suited,...
# 515  (Occasionally, and, exceptionally, a, solo, st...
# 516  (But, the, proper, function, of, the, Organ, i...
# 517  (The, composer, therefore, must, \n, not, writ...
# 518  (What, \n, is, commonplace, and, trite, can, n...
# 519  (It, must, therefore, be, banished, from, the,...
# 520    (How, clearly, Bach, grasped, that, fact, !,  )
# 521  (Even, his, secular, music, disdained, \n, tri...
# 522  (Much, more, so, his, Organ, music, ,, in, whi...
# 523  (Of, the, means, by, which, Bach, attained, to...
# 524  (The, \n, remoteness, of, the, ecclesiastical,...
# 525  (Any, one, who, looks, at, Bach, 's, simple, f...
# 526  (But, no, one, can, \n, realise, how, the, Org...
# 527  (It, becomes, a, choir, of, four, or, five, pa...
# 528  (Compare, the, following, chords, in, divided,...
# 529  ([, Divided, Harmony, ,, Bach, treatment, ], \...
# 530  (We, realise, instantly, the, \n, effect, when...
# 531  (Bach, \n, always, played, the, Organ, so, ,, ...
# 532  (He, employed, it, not, only, to, sound, the, ...
# 533  (To, these, qualities, must, be, added, the, e...
# 534  (His, registration, frequently, astonished, \n...
# 535  (Bach, 's, peculiar, registration, was, based,...
# 536  (Very, early, in, his, \n, career, he, made, a...
# 537  (Nothing, escaped, his, notice, which, had, th...
# 538  (For, instance, ,, he, made, a, point, of, obs...
# 539  (The, \n, practised, ear, ,, which, enabled, h...
# 540  (When, he, was, at, Berlin, in, 1747, he, was,...
# 541  (He, took, in, its, good, and, bad, qualities,...
# 542  (He, was, shown, the, large, adjoining, Saloon...
# 543  (Merely, glancing, at, the, \n, roof, he, rema...
# 544  (The, Saloon, ,, in, \n, fact, ,, is, a, paral...
# 545  (If, a, person, puts, his, face, to, the, wall...
# 546  (The, effect, arises, from, the, span, of, the...
# 547  (These, and, similar, \n, observations, sugges...
# 548  (Bach, brought, the, methods, I, have, indicat...
# 549  (His, profound, knowledge, of, harmony, ,, unf...
#
#                                      entities    character_entities
# 500             [Wilhelm Friedemann, Clavier]  [Wilhelm Friedemann]
# 501                                   [Organ]                    []
# 502                                        []                    []
# 503                                        []                    []
# 504                                        []                    []
# 505                      [Wilhelm Friedemann]  [Wilhelm Friedemann]
# 506                                   [Organ]                    []
# 507                                        []                    []
# 508                                        []                    []
# 509                                        []                    []
# 510                    [Bach, Clavier, Organ]                [Bach]
# 511                                        []                    []
# 512                                   [Organ]                    []
# 513                                        []                    []
# 514                                        []                    []
# 515                                        []                    []
# 516                                   [Organ]                    []
# 517                                        []                    []
# 518                                        []                    []
# 519                                   [Organ]                    []
# 520                                    [Bach]                [Bach]
# 521                                        []                    []
# 522                                   [Organ]                    []
# 523                     [Bach, Organ, Church]                [Bach]
# 524                         [our twenty-four]                    []
# 525                        [Bach, four, Hymn]                [Bach]
# 526                                   [Organ]                    []
# 527                            [four or five]                    []
# 528                                        []                    []
# 529  [Divided Harmony, Bach, Divided Harmony]                [Bach]
# 530                                    [four]                    []
# 531                                   [Organ]                    []
# 532                                    [five]                    []
# 533                             [Bach, Organ]                [Bach]
# 534                     [Organ, first, Organ]                    []
# 535                             [Bach, Organ]                [Bach]
# 536                                   [Organ]                    []
# 537                                        []                    []
# 538                                        []                    []
# 539                                        []                    []
# 540              [Berlin, 1747, Opera, House]                    []
# 541                                        []                    []
# 542                                  [Saloon]                    []
# 543                                        []                    []
# 544                                  [Saloon]                    []
# 545                                     [one]                    []
# 546                                    [Bach]                [Bach]
# 547                                   [Organ]                    []
# 548                            [Bach, Church]                [Bach]
# 549                                   [Organ]                    []

# %%
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].apply(len) > 0]
sent_entity_df_filtered
# Out:
#                                                sentence  \
# 1     (If, there, is, such, a, thing, as, inherited,...
# 3     (Veit, Bach, ,, ancestor, of, this, famous, fa...
# 14    (Johann, Christoph, Bach, ,, Court, and, Town,...
# 16    (In, the, _, Archives, of, the, Bachs, ,, whic...
# 17    (He, was, also, \n      , an, uncommon, master...
# ...                                                 ...
# 1317  (Even, \n, the, beginner, who, knows, but, the...
# 1318  (It, was, the, \n, true, artist, spirit, ,, to...
# 1319  (Bach, held, strongly, that, if, the, strands,...
# 1321  (To, conclude, :, it, was, the, union, of, ast...
# 1323  (If, Bach, was, more, successful, ,, if, he, w...
#
#                                                entities  \
# 1                                                [Bach]
# 3                       [Veit Bach, Pressburg, Hungary]
# 14             [Johann Christoph Bach, Court, Eisenach]
# 16    [Bachs, Carl Philipp Emmanuel's, Hamburg, Joha...
# 17                     [Michaelmas, Streit, twenty-two]
# ...                                                 ...
# 1317                                             [Bach]
# 1318                                             [Bach]
# 1319                                             [Bach]
# 1321                                             [Bach]
# 1323                                             [Bach]
#
#            character_entities
# 1                      [Bach]
# 3                 [Veit Bach]
# 14    [Johann Christoph Bach]
# 16         [Johann Christoph]
# 17               [Michaelmas]
# ...                       ...
# 1317                   [Bach]
# 1318                   [Bach]
# 1319                   [Bach]
# 1321                   [Bach]
# 1323                   [Bach]
#
# [378 rows x 3 columns]

# %% [markdown]
# ## Create relationships

# %%
window_size = 5
relationships = []

end_idx = sent_entity_df_filtered.index[-1]
for i in range(end_idx):
    end_i = min(i+window_size, end_idx)
    char_list = sum((sent_entity_df_filtered.loc[i:end_i].character_entities), [])
    #print(characters)
    char_unique = [char_list[i] for i in range(len(char_list)) if i == 0 or char_list[i] != char_list[i-1]]
    #char_unique = set()
    #for i in range(len(char_list)):
    #    char_unique.add(char_list[i])
    #print(char_unique)

    for idx, a in enumerate(char_unique[:-1]):
        b = char_unique[idx+1]
        relationships.append({'source': a, 'target': b})

# %%
relationships_df = pd.DataFrame(relationships)
pd.set_option('display.max_rows', None)
relationships_df.sort_values(by='source')
# Out:
#                             source                         target
# 603                           Alto                           Bach
# 602                           Alto                           Bach
# 600                           Alto                           Bach
# 595                           Alto                           Bach
# 593                           Alto                           Bach
# 594                           Alto                           Bach
# 226                 Anna Magdalena                           Bach
# 230                 Anna Magdalena                           Bach
# 228                 Anna Magdalena                           Bach
# 380                 Anna Magdalena          Carl Philipp Emmanuel
# 236                 Anna Magdalena                           Bach
# 378                 Anna Magdalena          Carl Philipp Emmanuel
# 375                 Anna Magdalena          Carl Philipp Emmanuel
# 218                 Anna Magdalena                           Bach
# 234                 Anna Magdalena                           Bach
# 216                 Anna Magdalena                           Bach
# 371                 Anna Magdalena          Carl Philipp Emmanuel
# 214                 Anna Magdalena                           Bach
# 366                 Anna Magdalena          Carl Philipp Emmanuel
# 220                 Anna Magdalena                           Bach
# 232                 Anna Magdalena                           Bach
# 303                           Bach                   Maria Amalia
# 670                           Bach                         Handel
# 307                           Bach      Johann Christian Hoffmann
# 0                             Bach                      Veit Bach
# 297                           Bach      Johann Christian Hoffmann
# 675                           Bach                         Handel
# 668                           Bach                         Handel
# 293                           Bach                   Maria Amalia
# 677                           Bach                         Handel
# 288                           Bach                   Maria Amalia
# 286                           Bach           another Bach Cantata
# 680                           Bach                         Handel
# 672                           Bach                         Handel
# 666                           Bach                         Handel
# 325                           Bach      Johann Christian Hoffmann
# 312                           Bach                   Maria Amalia
# 344                           Bach                         Peters
# 640                           Bach                      Brunswick
# 342                           Bach                         Peters
# 341                           Bach                         Peters
# 340                           Bach                         Peters
# 339                           Bach                         Peters
# 642                           Bach                      Brunswick
# 648                           Bach                Reinhard Keiser
# 665                           Bach                         Handel
# 330                           Bach      Johann Christian Hoffmann
# 652                           Bach                Reinhard Keiser
# 655                           Bach                Reinhard Keiser
# 283                           Bach                   Maria Amalia
# 321                           Bach                   Maria Amalia
# 658                           Bach                         Handel
# 659                           Bach                Reinhard Keiser
# 662                           Bach                         Handel
# 316                           Bach      Johann Christian Hoffmann
# 650                           Bach                Reinhard Keiser
# 281                           Bach           another Bach Cantata
# 686                           Bach                         Handel
# 279                           Bach           another Bach Cantata
# 240                           Bach         Johann Matthias Gesner
# 698                           Bach                         Handel
# 237                           Bach        Johann Heinrich Ernesti
# 235                           Bach        Johann Heinrich Ernesti
# 233                           Bach        Johann Heinrich Ernesti
# 231                           Bach        Johann Heinrich Ernesti
# 229                           Bach                 Anna Magdalena
# 227                           Bach                 Anna Magdalena
# 225                           Bach                 Anna Magdalena
# 241                           Bach         Johann Matthias Gesner
# 222                           Bach                     Michaelmas
# 219                           Bach                 Anna Magdalena
# 217                           Bach                 Anna Magdalena
# 215                           Bach                 Anna Magdalena
# 213                           Bach                 Anna Magdalena
# 212                           Bach                 Anna Magdalena
# 211                           Bach                 Anna Magdalena
# 701                           Bach                         Handel
# 705                           Bach                         Handel
# 206                           Bach                     Michaelmas
# 221                           Bach                     Michaelmas
# 243                           Bach         Johann Matthias Gesner
# 694                           Bach                         Handel
# 245                           Bach         Johann Matthias Gesner
# 554                           Bach                    Herein Bach
# 276                           Bach           another Bach Cantata
# 274                           Bach                         Müller
# 349                           Bach                  Fritz Volbach
# 272                           Bach                         Müller
# 270                           Bach                         Müller
# 269                           Bach                         Müller
# 688                           Bach                         Handel
# 267                           Bach          Vereinigte Zwietracht
# 265                           Bach          Vereinigte Zwietracht
# 264                           Bach          Vereinigte Zwietracht
# 263                           Bach          Vereinigte Zwietracht
# 262                           Bach          Vereinigte Zwietracht
# 261                           Bach          Vereinigte Zwietracht
# 258                           Bach                         Görner
# 256                           Bach                         Görner
# 254                           Bach                         Görner
# 252                           Bach                         Görner
# 250                           Bach                         Görner
# 692                           Bach                         Handel
# 247                           Bach         Johann Matthias Gesner
# 682                           Bach                         Handel
# 351                           Bach                  Fritz Volbach
# 635                           Bach          Carl Philipp Emmanuel
# 637                           Bach          Carl Philipp Emmanuel
# 502                           Bach                       Couperin
# 500                           Bach          Carl Philipp Emmanuel
# 498                           Bach                       Couperin
# 496                           Bach                       Couperin
# 494                           Bach          Carl Philipp Emmanuel
# 492                           Bach                       Couperin
# 490                           Bach                       Couperin
# 489                           Bach                       Couperin
# 487                           Bach                       Couperin
# 504                           Bach                       Couperin
# 485                           Bach          Carl Philipp Emmanuel
# 481                           Bach                       Couperin
# 479                           Bach                       Couperin
# 477                           Bach                       Couperin
# 475                           Bach          Carl Philipp Emmanuel
# 473                           Bach                       Couperin
# 471                           Bach                       Couperin
# 469                           Bach                       Couperin
# 468                           Bach                       Couperin
# 466                           Bach          Carl Philipp Emmanuel
# 483                           Bach                       Couperin
# 464                           Bach                       Couperin
# 507                           Bach          Carl Philipp Emmanuel
# 511                           Bach                       Couperin
# 556                           Bach                    Herein Bach
# 557                           Bach                    Herein Bach
# 558                           Bach                    Herein Bach
# 561                           Bach                Reinhard Keiser
# 564                           Bach                    Herein Bach
# 565                           Bach                    Herein Bach
# 532                           Bach                        Vivaldi
# 531                           Bach                        Vivaldi
# 530                           Bach                        Vivaldi
# 509                           Bach                       Couperin
# 529                           Bach                        Vivaldi
# 523                           Bach                 Sebastian Bach
# 522                           Bach                 Sebastian Bach
# 520                           Bach             Wilhelm Friedemann
# 519                           Bach             Wilhelm Friedemann
# 518                           Bach             Wilhelm Friedemann
# 517                           Bach             Wilhelm Friedemann
# 516                           Bach             Wilhelm Friedemann
# 515                           Bach             Wilhelm Friedemann
# 513                           Bach                       Couperin
# 524                           Bach                 Sebastian Bach
# 462                           Bach                       Couperin
# 460                           Bach                       Couperin
# 458                           Bach                       Couperin
# 404                           Bach   Johann Christoph Friedrich's
# 611                           Bach             Wilhelm Friedemann
# 399                           Bach   Johann Christoph Friedrich's
# 614                           Bach             Wilhelm Friedemann
# 394                           Bach   Johann Christoph Friedrich's
# 625                           Bach               Wahre Grundsätze
# 626                           Bach               Wahre Grundsätze
# 390                           Bach   Johann Christoph Friedrich's
# 627                           Bach               Wahre Grundsätze
# 608                           Bach             Wilhelm Friedemann
# 629                           Bach          Carl Philipp Emmanuel
# 377                           Bach                 Anna Magdalena
# 374                           Bach                 Anna Magdalena
# 633                           Bach          Carl Philipp Emmanuel
# 370                           Bach                 Anna Magdalena
# 365                           Bach                 Anna Magdalena
# 205                           Bach                     Michaelmas
# 362                           Bach                  Fritz Volbach
# 361                           Bach                 Anna Magdalena
# 358                           Bach                  Fritz Volbach
# 631                           Bach          Carl Philipp Emmanuel
# 606                           Bach             Wilhelm Friedemann
# 604                           Bach             Wilhelm Friedemann
# 410                           Bach   Johann Christoph Friedrich's
# 456                           Bach                       Couperin
# 453                           Bach                       Couperin
# 451                           Bach                       Couperin
# 449                           Bach                       Couperin
# 447                           Bach                       Couperin
# 445                           Bach                       Couperin
# 443                           Bach                       Couperin
# 441                           Bach                       Couperin
# 439                           Bach                       Couperin
# 574                           Bach                         Handel
# 577                           Bach                         Handel
# 579                           Bach                         Handel
# 581                           Bach                         Handel
# 585                           Bach          Johann Sebastian Bach
# 591                           Bach                           Alto
# 592                           Bach                           Alto
# 596                           Bach                           Alto
# 597                           Bach                           Alto
# 598                           Bach                           Alto
# 599                           Bach                           Alto
# 601                           Bach                           Alto
# 354                           Bach                  Fritz Volbach
# 204                           Bach                     Michaelmas
# 277                           Bach                         Müller
# 555                           Bach                    Herein Bach
# 136                           Bach          Carl Philipp Emmanuel
# 772                           Bach               Count Kaiserling
# 39                            Bach          Johann Sebastian Bach
# 90                            Bach               Johann Sebastian
# 35                            Bach          Johann Sebastian Bach
# 138                           Bach                   Carl Philipp
# 95                            Bach               Johann Sebastian
# 140                           Bach                   Carl Philipp
# 32                            Bach          Johann Sebastian Bach
# 780                           Bach          Carl Philipp Emmanuel
# 781                           Bach          Carl Philipp Emmanuel
# 43                            Bach          Johann Sebastian Bach
# 143                           Bach                   Carl Philipp
# 104                           Bach          Wasserflüssen Babylon
# 734                           Bach                     Friedemann
# 782                           Bach          Carl Philipp Emmanuel
# 148                           Bach                   Carl Philipp
# 732                           Bach                     Friedemann
# 783                           Bach          Carl Philipp Emmanuel
# 151                           Bach                   Carl Philipp
# 784                           Bach          Carl Philipp Emmanuel
# 785                           Bach          Carl Philipp Emmanuel
# 156                           Bach             Wilhelm Friedemann
# 157                           Bach             Wilhelm Friedemann
# 145                           Bach                   Carl Philipp
# 736                           Bach                     Friedemann
# 770                           Bach               Count Kaiserling
# 46                            Bach          Johann Sebastian Bach
# 738                           Bach                     Friedemann
# 89                            Bach               Johann Sebastian
# 110                           Bach          Carl Philipp Emmanuel
# 112                           Bach          Carl Philipp Emmanuel
# 114                           Bach          Carl Philipp Emmanuel
# 116                           Bach          Carl Philipp Emmanuel
# 106                           Bach          Wasserflüssen Babylon
# 118                           Bach          Carl Philipp Emmanuel
# 120                           Bach          Carl Philipp Emmanuel
# 746                           Bach                     Vom Himmel
# 749                           Bach                     Vom Himmel
# 122                           Bach                   Carl Philipp
# 123                           Bach          Carl Philipp Emmanuel
# 125                           Bach          Carl Philipp Emmanuel
# 127                           Bach                   Carl Philipp
# 752                           Bach                     Vom Himmel
# 753                           Bach                     Vom Himmel
# 130                           Bach          Carl Philipp Emmanuel
# 755                           Bach                     Vom Himmel
# 757                           Bach                     Vom Himmel
# 764                           Bach               Count Kaiserling
# 766                           Bach               Count Kaiserling
# 132                           Bach                   Carl Philipp
# 768                           Bach               Count Kaiserling
# 134                           Bach                   Carl Philipp
# 729                           Bach                     Friedemann
# 159                           Bach             Wilhelm Friedemann
# 88                            Bach               Johann Sebastian
# 787                           Bach             Wilhelm Friedemann
# 802                           Bach                      Pachelbel
# 804                           Bach                      Pachelbel
# 719                           Bach                          Hasse
# 176                           Bach                         Görner
# 178                           Bach                         Görner
# 92                            Bach               Johann Sebastian
# 180                           Bach                         Görner
# 716                           Bach                         Handel
# 182                           Bach                         Görner
# 93                            Bach               Johann Sebastian
# 184                           Bach                         Görner
# 94                            Bach               Johann Sebastian
# 809                           Bach             Wilhelm Friedemann
# 810                           Bach             Wilhelm Friedemann
# 187                           Bach                        Nicolas
# 812                           Bach             Wilhelm Friedemann
# 714                           Bach                          Hasse
# 823                           Bach                        Vivaldi
# 814                           Bach             Wilhelm Friedemann
# 197                           Bach                    Paul Wagner
# 816                           Bach             Wilhelm Friedemann
# 711                           Bach                         Handel
# 822                           Bach                        Vivaldi
# 194                           Bach                    Paul Wagner
# 195                           Bach                    Paul Wagner
# 722                           Bach                          Hasse
# 203                           Bach                     Michaelmas
# 808                           Bach             Wilhelm Friedemann
# 800                           Bach                      Pachelbel
# 103                           Bach          Wasserflüssen Babylon
# 789                           Bach             Wilhelm Friedemann
# 161                           Bach             Wilhelm Friedemann
# 791                           Bach             Wilhelm Friedemann
# 201                           Bach                    Paul Wagner
# 727                           Bach                          Hasse
# 793                           Bach             Wilhelm Friedemann
# 163                           Bach             Wilhelm Friedemann
# 824                           Bach                        Vivaldi
# 726                           Bach                     Friedemann
# 102                           Bach          Wasserflüssen Babylon
# 1                             Bach                      Veit Bach
# 797                           Bach                      Pachelbel
# 196                           Bach                    Paul Wagner
# 170                           Bach               Philipp Telemann
# 166                           Bach               Philipp Telemann
# 199                           Bach                    Paul Wagner
# 91                            Bach               Johann Sebastian
# 826                           Bach                        Vivaldi
# 167                           Bach               Philipp Telemann
# 724                           Bach                          Hasse
# 168                           Bach               Philipp Telemann
# 798                           Bach                      Pachelbel
# 385                      Beethoven                 Regine Susanna
# 392                      Beethoven                 Regine Susanna
# 402                      Beethoven                 Regine Susanna
# 397                      Beethoven                 Regine Susanna
# 388                      Beethoven                 Regine Susanna
# 646                      Brunswick                           Bach
# 645                      Brunswick                           Bach
# 641                      Brunswick                           Bach
# 644                      Brunswick                           Bach
# 643                      Brunswick                           Bach
# 647                      Brunswick                           Bach
# 80                            Böhm               Johann Christoph
# 64                            Böhm               Johann Christoph
# 70                            Böhm               Johann Christoph
# 75                            Böhm               Johann Christoph
# 85                            Böhm               Johann Christoph
# 146                   Carl Philipp             Wilhelm Friedemann
# 435                   Carl Philipp                           Bach
# 436                   Carl Philipp                           Bach
# 437                   Carl Philipp                           Bach
# 438                   Carl Philipp                           Bach
# 128                   Carl Philipp                           Bach
# 133                   Carl Philipp                           Bach
# 135                   Carl Philipp             Wilhelm Friedemann
# 139                   Carl Philipp                           Bach
# 434                   Carl Philipp                           Bach
# 141                   Carl Philipp             Wilhelm Friedemann
# 144                   Carl Philipp                           Bach
# 154                   Carl Philipp             Wilhelm Friedemann
# 147                   Carl Philipp                           Bach
# 149                   Carl Philipp             Wilhelm Friedemann
# 152                   Carl Philipp             Wilhelm Friedemann
# 632          Carl Philipp Emmanuel                           Bach
# 630          Carl Philipp Emmanuel                           Bach
# 382          Carl Philipp Emmanuel             Wilhelm Friedemann
# 381          Carl Philipp Emmanuel             Wilhelm Friedemann
# 376          Carl Philipp Emmanuel             Wilhelm Friedemann
# 486          Carl Philipp Emmanuel                           Bach
# 616          Carl Philipp Emmanuel                           Bach
# 569          Carl Philipp Emmanuel                           Bach
# 570          Carl Philipp Emmanuel                           Bach
# 571          Carl Philipp Emmanuel                           Bach
# 572          Carl Philipp Emmanuel                           Bach
# 573          Carl Philipp Emmanuel                           Bach
# 15           Carl Philipp Emmanuel            Johann Michael Bach
# 16           Carl Philipp Emmanuel            Johann Michael Bach
# 18           Carl Philipp Emmanuel            Johann Michael Bach
# 508          Carl Philipp Emmanuel                           Bach
# 786          Carl Philipp Emmanuel                           Bach
# 501          Carl Philipp Emmanuel                           Bach
# 495          Carl Philipp Emmanuel                           Bach
# 476          Carl Philipp Emmanuel                           Bach
# 467          Carl Philipp Emmanuel                           Bach
# 576          Carl Philipp Emmanuel                           Bach
# 610          Carl Philipp Emmanuel                           Bach
# 613          Carl Philipp Emmanuel                           Bach
# 618          Carl Philipp Emmanuel                           Bach
# 372          Carl Philipp Emmanuel             Wilhelm Friedemann
# 379          Carl Philipp Emmanuel             Wilhelm Friedemann
# 119          Carl Philipp Emmanuel                           Bach
# 124          Carl Philipp Emmanuel                           Bach
# 142          Carl Philipp Emmanuel                           Bach
# 129          Carl Philipp Emmanuel                           Bach
# 131          Carl Philipp Emmanuel                           Bach
# 121          Carl Philipp Emmanuel                           Bach
# 117          Carl Philipp Emmanuel                           Bach
# 115          Carl Philipp Emmanuel                           Bach
# 113          Carl Philipp Emmanuel                           Bach
# 111          Carl Philipp Emmanuel                           Bach
# 639          Carl Philipp Emmanuel                           Bach
# 638          Carl Philipp Emmanuel                           Bach
# 126          Carl Philipp Emmanuel                           Bach
# 636          Carl Philipp Emmanuel                           Bach
# 634          Carl Philipp Emmanuel                           Bach
# 367          Carl Philipp Emmanuel             Wilhelm Friedemann
# 137          Carl Philipp Emmanuel                           Bach
# 58                     Caspar Kerl                      Pachelbel
# 78                     Caspar Kerl                      Pachelbel
# 62                     Caspar Kerl                      Pachelbel
# 73                     Caspar Kerl                      Pachelbel
# 83                     Caspar Kerl                      Pachelbel
# 68                     Caspar Kerl                      Pachelbel
# 296                    Charles III                           Bach
# 291                    Charles III                           Bach
# 315                    Charles III                           Bach
# 324                    Charles III                           Bach
# 306                    Charles III                           Bach
# 305              Charles of Sicily                    Charles III
# 295              Charles of Sicily                    Charles III
# 323              Charles of Sicily                    Charles III
# 290              Charles of Sicily                    Charles III
# 285              Charles of Sicily                    Charles III
# 314              Charles of Sicily                    Charles III
# 759             Christopher Weigel             Johann G. Schübler
# 774               Count Kaiserling                           Bach
# 771               Count Kaiserling                           Bach
# 769               Count Kaiserling                           Bach
# 773               Count Kaiserling                           Bach
# 767               Count Kaiserling                           Bach
# 765               Count Kaiserling                           Bach
# 454                       Couperin                           Bach
# 482                       Couperin                           Bach
# 465                       Couperin                           Bach
# 478                       Couperin                           Bach
# 97                        Couperin                           Bach
# 463                       Couperin                           Bach
# 488                       Couperin                           Bach
# 440                       Couperin                           Bach
# 470                       Couperin                           Bach
# 442                       Couperin                           Bach
# 461                       Couperin                           Bach
# 484                       Couperin                           Bach
# 446                       Couperin                           Bach
# 459                       Couperin                           Bach
# 472                       Couperin                           Bach
# 448                       Couperin                           Bach
# 474                       Couperin                           Bach
# 457                       Couperin                           Bach
# 450                       Couperin                           Bach
# 455                       Couperin                           Bach
# 444                       Couperin                           Bach
# 452                       Couperin                           Bach
# 497                       Couperin                           Bach
# 491                       Couperin                           Bach
# 98                        Couperin                           Bach
# 99                        Couperin                           Bach
# 100                       Couperin                           Bach
# 101                       Couperin                           Bach
# 514                       Couperin                           Bach
# 512                       Couperin                           Bach
# 510                       Couperin                           Bach
# 506                       Couperin                           Bach
# 480                       Couperin                           Bach
# 503                       Couperin                           Bach
# 493                       Couperin                           Bach
# 505                       Couperin                           Bach
# 499                       Couperin                           Bach
# 748  Duke Christian of Weissenfels                           Bach
# 751  Duke Christian of Weissenfels                           Bach
# 745  Duke Christian of Weissenfels                           Bach
# 743  Duke Christian of Weissenfels                           Bach
# 750                     Duke Ernst  Duke Christian of Weissenfels
# 740                     Duke Ernst  Duke Christian of Weissenfels
# 741                     Duke Ernst  Duke Christian of Weissenfels
# 747                     Duke Ernst  Duke Christian of Weissenfels
# 742                     Duke Ernst  Duke Christian of Weissenfels
# 744                     Duke Ernst  Duke Christian of Weissenfels
# 346       Elias Gottlieb Haussmann                           Bach
# 348       Elias Gottlieb Haussmann                           Bach
# 350       Elias Gottlieb Haussmann                           Bach
# 353       Elias Gottlieb Haussmann                           Bach
# 357       Elias Gottlieb Haussmann                           Bach
# 553                        Fischer                           Bach
# 545                        Fischer                           Bach
# 549                        Fischer                           Bach
# 779                   Frederick II                           Bach
# 777                   Frederick II                           Bach
# 778                   Frederick II                           Bach
# 776                   Frederick II                           Bach
# 775                   Frederick II                           Bach
# 546                    Frescobaldi                      Froberger
# 542                    Frescobaldi                      Froberger
# 536                    Frescobaldi                      Froberger
# 533                    Frescobaldi                      Froberger
# 550                    Frescobaldi                      Froberger
# 539                    Frescobaldi                      Froberger
# 730                     Friedemann                           Bach
# 737                     Friedemann                           Bach
# 733                     Friedemann                           Bach
# 735                     Friedemann                           Bach
# 739                     Friedemann                           Bach
# 368                  Fritz Volbach                      Haussmann
# 363                  Fritz Volbach                      Haussmann
# 359                  Fritz Volbach                      Haussmann
# 355                  Fritz Volbach                      Haussmann
# 352                  Fritz Volbach                      Haussmann
# 72                       Froberger                    Caspar Kerl
# 67                       Froberger                    Caspar Kerl
# 82                       Froberger                    Caspar Kerl
# 534                      Froberger                           Kerl
# 77                       Froberger                    Caspar Kerl
# 537                      Froberger                           Kerl
# 61                       Froberger                    Caspar Kerl
# 543                      Froberger                           Kerl
# 547                      Froberger                           Kerl
# 57                       Froberger                    Caspar Kerl
# 551                      Froberger                           Kerl
# 540                      Froberger                           Kerl
# 255                         Görner                           Bach
# 251                         Görner                           Bach
# 185                         Görner                           Bach
# 260                         Görner                           Bach
# 183                         Görner                           Bach
# 259                         Görner                           Bach
# 253                         Görner                           Bach
# 257                         Görner                           Bach
# 186                         Görner                           Bach
# 699                         Handel                          Hasse
# 700                         Handel                           Bach
# 674                         Handel                           Bach
# 712                         Handel                          Hasse
# 717                         Handel                          Hasse
# 710                         Handel                           Bach
# 708                         Handel             Wilhelm Friedemann
# 702                         Handel             Wilhelm Friedemann
# 704                         Handel                           Bach
# 715                         Handel                           Bach
# 720                         Handel                          Hasse
# 693                         Handel                           Bach
# 697                         Handel                           Bach
# 673                         Handel                           Bach
# 671                         Handel                           Bach
# 669                         Handel                           Bach
# 678                         Handel             Wilhelm Friedemann
# 667                         Handel                           Bach
# 575                         Handel                           Bach
# 578                         Handel                           Bach
# 580                         Handel                           Bach
# 681                         Handel                           Bach
# 683                         Handel             Wilhelm Friedemann
# 685                         Handel                           Bach
# 582                         Handel                           Bach
# 687                         Handel                           Bach
# 706                         Handel                          Hasse
# 583                         Handel                           Bach
# 584                         Handel                           Bach
# 695                         Handel             Wilhelm Friedemann
# 676                         Handel                           Bach
# 691                         Handel                           Bach
# 689                         Handel             Wilhelm Friedemann
# 718                          Hasse                           Bach
# 707                          Hasse                           Bach
# 723                          Hasse                           Bach
# 725                          Hasse                           Bach
# 731                          Hasse                           Bach
# 654                          Hasse                           Bach
# 728                          Hasse                           Bach
# 713                          Hasse                           Bach
# 657                          Hasse                           Bach
# 721                          Hasse                           Bach
# 664                          Hasse                           Bach
# 661                          Hasse                           Bach
# 414                      Haussmann          Johann Sebastian Bach
# 424                      Haussmann                           Bach
# 422                      Haussmann          Johann Sebastian Bach
# 408                      Haussmann          Johann Sebastian Bach
# 426                      Haussmann          Johann Sebastian Bach
# 428                      Haussmann                           Bach
# 429                      Haussmann          Johann Sebastian Bach
# 418                      Haussmann          Johann Sebastian Bach
# 432                      Haussmann                           Bach
# 433                      Haussmann                           Bach
# 373                      Haussmann                           Bach
# 369                      Haussmann                           Bach
# 364                      Haussmann                           Bach
# 431                      Haussmann                           Bach
# 360                      Haussmann                           Bach
# 356                      Haussmann                           Bach
# 567                    Herein Bach                           Bach
# 566                    Herein Bach                           Bach
# 560                    Herein Bach                           Bach
# 568                    Herein Bach                           Bach
# 559                    Herein Bach                           Bach
# 310                J. C. Gottsched        Johann Abraham Birnbaum
# 328                J. C. Gottsched        Johann Abraham Birnbaum
# 319                J. C. Gottsched        Johann Abraham Birnbaum
# 333                J. C. Gottsched        Johann Abraham Birnbaum
# 300                J. C. Gottsched        Johann Abraham Birnbaum
# 337                J. C. Gottsched        Johann Abraham Birnbaum
# 334        Johann Abraham Birnbaum                           Bach
# 301        Johann Abraham Birnbaum                           Bach
# 329        Johann Abraham Birnbaum                           Bach
# 338        Johann Abraham Birnbaum                           Bach
# 320        Johann Abraham Birnbaum                           Bach
# 311        Johann Abraham Birnbaum                           Bach
# 45           Johann Ambrosius Bach               Johann Christoph
# 48           Johann Ambrosius Bach               Johann Christoph
# 50           Johann Ambrosius Bach               Johann Christoph
# 37           Johann Ambrosius Bach               Johann Christoph
# 41           Johann Ambrosius Bach               Johann Christoph
# 26            Johann Bernhard Bach               Johann Sebastian
# 27            Johann Bernhard Bach               Johann Sebastian
# 29            Johann Bernhard Bach               Johann Sebastian
# 28            Johann Bernhard Bach               Johann Sebastian
# 308      Johann Christian Hoffmann           Marianne von Ziegler
# 317      Johann Christian Hoffmann           Marianne von Ziegler
# 326      Johann Christian Hoffmann           Marianne von Ziegler
# 298      Johann Christian Hoffmann           Marianne von Ziegler
# 331      Johann Christian Hoffmann           Marianne von Ziegler
# 335      Johann Christian Hoffmann           Marianne von Ziegler
# 66                Johann Christoph                      Froberger
# 60                Johann Christoph                      Froberger
# 71                Johann Christoph                           Bach
# 76                Johann Christoph                           Bach
# 56                Johann Christoph                      Froberger
# 51                Johann Christoph               Johann Sebastian
# 65                Johann Christoph                           Bach
# 86                Johann Christoph                           Bach
# 25                Johann Christoph           Johann Bernhard Bach
# 81                Johann Christoph                           Bach
# 24                Johann Christoph           Johann Bernhard Bach
# 6                 Johann Christoph                     Michaelmas
# 22                Johann Christoph           Johann Bernhard Bach
# 8                 Johann Christoph                     Michaelmas
# 87                Johann Christoph                           Bach
# 10                Johann Christoph                     Michaelmas
# 12                Johann Christoph                     Michaelmas
# 4                 Johann Christoph                     Michaelmas
# 5            Johann Christoph Bach               Johann Christoph
# 7            Johann Christoph Bach               Johann Christoph
# 2            Johann Christoph Bach               Johann Christoph
# 3            Johann Christoph Bach               Johann Christoph
# 405   Johann Christoph Friedrich's                 Sebastian Bach
# 415   Johann Christoph Friedrich's                 Sebastian Bach
# 395   Johann Christoph Friedrich's                 Sebastian Bach
# 411   Johann Christoph Friedrich's                 Sebastian Bach
# 400   Johann Christoph Friedrich's                 Sebastian Bach
# 763             Johann G. Schübler                           Bach
# 762             Johann G. Schübler                           Bach
# 761             Johann G. Schübler                           Bach
# 760             Johann G. Schübler                           Bach
# 179         Johann Gottlieb Görner                           Bach
# 177         Johann Gottlieb Görner                           Bach
# 175         Johann Gottlieb Görner                           Bach
# 174         Johann Gottlieb Görner                           Bach
# 181         Johann Gottlieb Görner                           Bach
# 239        Johann Heinrich Ernesti                           Bach
# 238        Johann Heinrich Ernesti                           Bach
# 242         Johann Matthias Gesner                           Bach
# 244         Johann Matthias Gesner                           Bach
# 246         Johann Matthias Gesner                           Bach
# 249         Johann Matthias Gesner                           Bach
# 248         Johann Matthias Gesner                           Bach
# 17             Johann Michael Bach               Johann Christoph
# 19             Johann Michael Bach               Johann Christoph
# 20             Johann Michael Bach               Johann Christoph
# 21             Johann Michael Bach               Johann Christoph
# 23             Johann Michael Bach               Johann Christoph
# 53                Johann Sebastian               Johann Christoph
# 54                Johann Sebastian               Johann Christoph
# 96                Johann Sebastian                       Couperin
# 55                Johann Sebastian               Johann Christoph
# 52                Johann Sebastian               Johann Christoph
# 36           Johann Sebastian Bach          Johann Ambrosius Bach
# 430          Johann Sebastian Bach                      Haussmann
# 427          Johann Sebastian Bach                      Haussmann
# 425          Johann Sebastian Bach                      Haussmann
# 423          Johann Sebastian Bach                      Haussmann
# 586          Johann Sebastian Bach                          Fritz
# 587          Johann Sebastian Bach                          Fritz
# 588          Johann Sebastian Bach                          Fritz
# 589          Johann Sebastian Bach                          Fritz
# 590          Johann Sebastian Bach                          Fritz
# 40           Johann Sebastian Bach          Johann Ambrosius Bach
# 421          Johann Sebastian Bach                      Haussmann
# 419          Johann Sebastian Bach                      Haussmann
# 417          Johann Sebastian Bach                      Haussmann
# 47           Johann Sebastian Bach          Johann Ambrosius Bach
# 44           Johann Sebastian Bach          Johann Ambrosius Bach
# 413          Johann Sebastian Bach                      Haussmann
# 42           Johann Sebastian Bach                           Bach
# 407          Johann Sebastian Bach                      Haussmann
# 30           Johann Sebastian Bach                           Bach
# 31           Johann Sebastian Bach                           Bach
# 33           Johann Sebastian Bach          Johann Ambrosius Bach
# 34           Johann Sebastian Bach                           Bach
# 49           Johann Sebastian Bach          Johann Ambrosius Bach
# 38           Johann Sebastian Bach                           Bach
# 552                           Kerl                        Fischer
# 548                           Kerl                        Fischer
# 535                           Kerl                        Fischer
# 544                           Kerl                        Fischer
# 538                           Kerl                        Fischer
# 541                           Kerl                        Fischer
# 322                   Maria Amalia              Charles of Sicily
# 313                   Maria Amalia              Charles of Sicily
# 304                   Maria Amalia              Charles of Sicily
# 294                   Maria Amalia              Charles of Sicily
# 284                   Maria Amalia              Charles of Sicily
# 289                   Maria Amalia              Charles of Sicily
# 309           Marianne von Ziegler                J. C. Gottsched
# 318           Marianne von Ziegler                J. C. Gottsched
# 332           Marianne von Ziegler                J. C. Gottsched
# 299           Marianne von Ziegler                J. C. Gottsched
# 336           Marianne von Ziegler                J. C. Gottsched
# 327           Marianne von Ziegler                J. C. Gottsched
# 224                     Michaelmas                           Bach
# 223                     Michaelmas                           Bach
# 210                     Michaelmas                           Bach
# 209                     Michaelmas                           Bach
# 13                      Michaelmas          Carl Philipp Emmanuel
# 208                     Michaelmas                           Bach
# 207                     Michaelmas                           Bach
# 11                      Michaelmas          Carl Philipp Emmanuel
# 9                       Michaelmas          Carl Philipp Emmanuel
# 14                      Michaelmas          Carl Philipp Emmanuel
# 280                         Müller                           Bach
# 271                         Müller                           Bach
# 278                         Müller                           Bach
# 275                         Müller                           Bach
# 273                         Müller                           Bach
# 189                        Nicolas                           Bach
# 188                        Nicolas                           Bach
# 192                        Nicolas                           Bach
# 193                        Nicolas                           Bach
# 191                        Nicolas                           Bach
# 190                        Nicolas                           Bach
# 801                      Pachelbel                           Bach
# 74                       Pachelbel                           Böhm
# 63                       Pachelbel                           Böhm
# 84                       Pachelbel                           Böhm
# 79                       Pachelbel                           Böhm
# 69                       Pachelbel                           Böhm
# 799                      Pachelbel                           Bach
# 803                      Pachelbel                           Bach
# 805                      Pachelbel                           Bach
# 59                       Pachelbel                           Böhm
# 807                      Pachelbel                           Bach
# 806                      Pachelbel                           Bach
# 202                    Paul Wagner                           Bach
# 200                    Paul Wagner                           Bach
# 198                    Paul Wagner                           Bach
# 345                         Peters       Elias Gottlieb Haussmann
# 343                         Peters       Elias Gottlieb Haussmann
# 347                         Peters       Elias Gottlieb Haussmann
# 172               Philipp Telemann                           Bach
# 173               Philipp Telemann                           Bach
# 169               Philipp Telemann                           Bach
# 171               Philipp Telemann                           Bach
# 386                 Regine Susanna                           Bach
# 384                 Regine Susanna                      Beethoven
# 387                 Regine Susanna                      Beethoven
# 389                 Regine Susanna                           Bach
# 391                 Regine Susanna                      Beethoven
# 393                 Regine Susanna                           Bach
# 409                 Regine Susanna                           Bach
# 403                 Regine Susanna                           Bach
# 383                 Regine Susanna                      Beethoven
# 396                 Regine Susanna                      Beethoven
# 398                 Regine Susanna                           Bach
# 651                Reinhard Keiser                          Hasse
# 562                Reinhard Keiser                           Bach
# 649                Reinhard Keiser                          Hasse
# 663                Reinhard Keiser                          Hasse
# 563                Reinhard Keiser                           Bach
# 660                Reinhard Keiser                          Hasse
# 656                Reinhard Keiser                          Hasse
# 653                Reinhard Keiser                          Hasse
# 526                 Sebastian Bach                           Bach
# 527                 Sebastian Bach                           Bach
# 528                 Sebastian Bach                           Bach
# 416                 Sebastian Bach          Johann Sebastian Bach
# 525                 Sebastian Bach                           Bach
# 420                 Sebastian Bach          Johann Sebastian Bach
# 401                 Sebastian Bach          Johann Sebastian Bach
# 412                 Sebastian Bach          Johann Sebastian Bach
# 406                 Sebastian Bach          Johann Sebastian Bach
# 268          Vereinigte Zwietracht                           Bach
# 266          Vereinigte Zwietracht                           Bach
# 825                        Vivaldi                           Bach
# 827                        Vivaldi                           Bach
# 828                        Vivaldi                           Bach
# 829                        Vivaldi                           Bach
# 756                     Vom Himmel                           Bach
# 754                     Vom Himmel                           Bach
# 758                     Vom Himmel                           Bach
# 628               Wahre Grundsätze                           Bach
# 109          Wasserflüssen Babylon                           Bach
# 108          Wasserflüssen Babylon                           Bach
# 107          Wasserflüssen Babylon                           Bach
# 105          Wasserflüssen Babylon                           Bach
# 160             Wilhelm Friedemann                           Bach
# 162             Wilhelm Friedemann                           Bach
# 164             Wilhelm Friedemann                           Bach
# 165             Wilhelm Friedemann                           Bach
# 811             Wilhelm Friedemann                           Bach
# 158             Wilhelm Friedemann                           Bach
# 617             Wilhelm Friedemann          Carl Philipp Emmanuel
# 709             Wilhelm Friedemann                         Handel
# 815             Wilhelm Friedemann                           Bach
# 703             Wilhelm Friedemann                         Handel
# 817             Wilhelm Friedemann                           Bach
# 818             Wilhelm Friedemann                           Bach
# 819             Wilhelm Friedemann                           Bach
# 820             Wilhelm Friedemann                           Bach
# 821             Wilhelm Friedemann                           Bach
# 696             Wilhelm Friedemann                         Handel
# 679             Wilhelm Friedemann                         Handel
# 690             Wilhelm Friedemann                         Handel
# 813             Wilhelm Friedemann                           Bach
# 155             Wilhelm Friedemann                           Bach
# 150             Wilhelm Friedemann                           Bach
# 615             Wilhelm Friedemann          Carl Philipp Emmanuel
# 612             Wilhelm Friedemann          Carl Philipp Emmanuel
# 619             Wilhelm Friedemann                           Bach
# 620             Wilhelm Friedemann                           Bach
# 609             Wilhelm Friedemann          Carl Philipp Emmanuel
# 607             Wilhelm Friedemann          Carl Philipp Emmanuel
# 621             Wilhelm Friedemann                           Bach
# 605             Wilhelm Friedemann          Carl Philipp Emmanuel
# 153             Wilhelm Friedemann                           Bach
# 623             Wilhelm Friedemann                           Bach
# 622             Wilhelm Friedemann                           Bach
# 624             Wilhelm Friedemann                           Bach
# 790             Wilhelm Friedemann                      Brunswick
# 792             Wilhelm Friedemann                      Brunswick
# 794             Wilhelm Friedemann                      Brunswick
# 795             Wilhelm Friedemann                      Brunswick
# 796             Wilhelm Friedemann                      Brunswick
# 521             Wilhelm Friedemann                           Bach
# 788             Wilhelm Friedemann                      Brunswick
# 684             Wilhelm Friedemann                         Handel
# 302           another Bach Cantata                           Bach
# 292           another Bach Cantata                           Bach
# 287           another Bach Cantata                           Bach
# 282           another Bach Cantata                           Bach

# %%
relationships_df['value'] = 1
relationships_df.groupby(['source', 'target'], sort=False, as_index=False).sum()
# Out:
#                             source                         target  value
# 0                             Bach                      Veit Bach      2
# 1            Johann Christoph Bach               Johann Christoph      4
# 2                 Johann Christoph                     Michaelmas      5
# 3                       Michaelmas          Carl Philipp Emmanuel      4
# 4            Carl Philipp Emmanuel            Johann Michael Bach      3
# 5              Johann Michael Bach               Johann Christoph      5
# 6                 Johann Christoph           Johann Bernhard Bach      3
# 7             Johann Bernhard Bach               Johann Sebastian      4
# 8            Johann Sebastian Bach                           Bach      5
# 9                             Bach          Johann Sebastian Bach      6
# 10           Johann Sebastian Bach          Johann Ambrosius Bach      6
# 11           Johann Ambrosius Bach               Johann Christoph      5
# 12                Johann Christoph               Johann Sebastian      1
# 13                Johann Sebastian               Johann Christoph      4
# 14                Johann Christoph                      Froberger      3
# 15                       Froberger                    Caspar Kerl      6
# 16                     Caspar Kerl                      Pachelbel      6
# 17                       Pachelbel                           Böhm      6
# 18                            Böhm               Johann Christoph      5
# 19                Johann Christoph                           Bach      6
# 20                            Bach               Johann Sebastian      8
# 21                Johann Sebastian                       Couperin      1
# 22                        Couperin                           Bach     37
# 23                            Bach          Wasserflüssen Babylon      4
# 24           Wasserflüssen Babylon                           Bach      4
# 25                            Bach          Carl Philipp Emmanuel     27
# 26           Carl Philipp Emmanuel                           Bach     35
# 27                            Bach                   Carl Philipp     10
# 28                    Carl Philipp                           Bach     10
# 29                    Carl Philipp             Wilhelm Friedemann      6
# 30              Wilhelm Friedemann                           Bach     23
# 31                            Bach             Wilhelm Friedemann     26
# 32                            Bach               Philipp Telemann      4
# 33                Philipp Telemann                           Bach      4
# 34          Johann Gottlieb Görner                           Bach      5
# 35                            Bach                         Görner     10
# 36                          Görner                           Bach      9
# 37                            Bach                        Nicolas      1
# 38                         Nicolas                           Bach      6
# 39                            Bach                    Paul Wagner      6
# 40                     Paul Wagner                           Bach      3
# 41                            Bach                     Michaelmas      6
# 42                      Michaelmas                           Bach      6
# 43                            Bach                 Anna Magdalena     14
# 44                  Anna Magdalena                           Bach     10
# 45                            Bach        Johann Heinrich Ernesti      4
# 46         Johann Heinrich Ernesti                           Bach      2
# 47                            Bach         Johann Matthias Gesner      5
# 48          Johann Matthias Gesner                           Bach      5
# 49                            Bach          Vereinigte Zwietracht      6
# 50           Vereinigte Zwietracht                           Bach      2
# 51                            Bach                         Müller      5
# 52                          Müller                           Bach      5
# 53                            Bach           another Bach Cantata      4
# 54            another Bach Cantata                           Bach      4
# 55                            Bach                   Maria Amalia      6
# 56                    Maria Amalia              Charles of Sicily      6
# 57               Charles of Sicily                    Charles III      6
# 58                     Charles III                           Bach      5
# 59                            Bach      Johann Christian Hoffmann      5
# 60       Johann Christian Hoffmann           Marianne von Ziegler      6
# 61            Marianne von Ziegler                J. C. Gottsched      6
# 62                 J. C. Gottsched        Johann Abraham Birnbaum      6
# 63         Johann Abraham Birnbaum                           Bach      6
# 64                            Bach                         Peters      5
# 65                          Peters       Elias Gottlieb Haussmann      3
# 66        Elias Gottlieb Haussmann                           Bach      5
# 67                            Bach                  Fritz Volbach      5
# 68                   Fritz Volbach                      Haussmann      5
# 69                       Haussmann                           Bach     10
# 70                  Anna Magdalena          Carl Philipp Emmanuel      5
# 71           Carl Philipp Emmanuel             Wilhelm Friedemann      6
# 72                  Regine Susanna                      Beethoven      5
# 73                       Beethoven                 Regine Susanna      5
# 74                  Regine Susanna                           Bach      6
# 75                            Bach   Johann Christoph Friedrich's      5
# 76    Johann Christoph Friedrich's                 Sebastian Bach      5
# 77                  Sebastian Bach          Johann Sebastian Bach      5
# 78           Johann Sebastian Bach                      Haussmann      9
# 79                       Haussmann          Johann Sebastian Bach      6
# 80                            Bach                       Couperin     32
# 81                            Bach                 Sebastian Bach      3
# 82                  Sebastian Bach                           Bach      4
# 83                            Bach                        Vivaldi      8
# 84                     Frescobaldi                      Froberger      6
# 85                       Froberger                           Kerl      6
# 86                            Kerl                        Fischer      6
# 87                         Fischer                           Bach      3
# 88                            Bach                    Herein Bach      7
# 89                     Herein Bach                           Bach      5
# 90                            Bach                Reinhard Keiser      6
# 91                 Reinhard Keiser                           Bach      2
# 92                            Bach                         Handel     24
# 93                          Handel                           Bach     22
# 94           Johann Sebastian Bach                          Fritz      5
# 95                            Bach                           Alto      7
# 96                            Alto                           Bach      6
# 97              Wilhelm Friedemann          Carl Philipp Emmanuel      6
# 98                            Bach               Wahre Grundsätze      3
# 99                Wahre Grundsätze                           Bach      1
# 100                           Bach                      Brunswick      2
# 101                      Brunswick                           Bach      6
# 102                Reinhard Keiser                          Hasse      6
# 103                          Hasse                           Bach     12
# 104                         Handel             Wilhelm Friedemann      6
# 105             Wilhelm Friedemann                         Handel      6
# 106                         Handel                          Hasse      5
# 107                           Bach                          Hasse      5
# 108                           Bach                     Friedemann      6
# 109                     Friedemann                           Bach      5
# 110                     Duke Ernst  Duke Christian of Weissenfels      6
# 111  Duke Christian of Weissenfels                           Bach      4
# 112                           Bach                     Vom Himmel      6
# 113                     Vom Himmel                           Bach      3
# 114             Christopher Weigel             Johann G. Schübler      1
# 115             Johann G. Schübler                           Bach      4
# 116                           Bach               Count Kaiserling      5
# 117               Count Kaiserling                           Bach      6
# 118                   Frederick II                           Bach      5
# 119             Wilhelm Friedemann                      Brunswick      6
# 120                           Bach                      Pachelbel      5
# 121                      Pachelbel                           Bach      6
# 122                        Vivaldi                           Bach      4

# %%
import networkx as nx
G = nx.from_pandas_edgelist(relationships_df,
                            source = 'source',
                            target = 'target',
                            edge_attr = 'value',
                            create_using=nx.Graph())

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, ax=ax, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos)
plt.show()

# %%
#!pip3 install pyvis
from pyvis.network import Network
net = Network(notebook=True, width='1000px', height='700px', bgcolor='#222222', font_color='white')

#node_degree = dict(G.degree)
#nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G, edge_scaling=True, show_edge_weights=True)
net.show('bach.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# bach.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="bach.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## The most important character

# %%
degree_dict = nx.degree_centrality(G)
degree_dict
# Out:
# {'Bach': 0.75,
#  'Veit Bach': 0.015625,
#  'Johann Christoph Bach': 0.015625,
#  'Johann Christoph': 0.140625,
#  'Michaelmas': 0.046875,
#  'Carl Philipp Emmanuel': 0.078125,
#  'Johann Michael Bach': 0.03125,
#  'Johann Bernhard Bach': 0.03125,
#  'Johann Sebastian': 0.0625,
#  'Johann Sebastian Bach': 0.078125,
#  'Johann Ambrosius Bach': 0.03125,
#  'Froberger': 0.0625,
#  'Caspar Kerl': 0.03125,
#  'Pachelbel': 0.046875,
#  'Böhm': 0.03125,
#  'Couperin': 0.03125,
#  'Wasserflüssen Babylon': 0.015625,
#  'Carl Philipp': 0.03125,
#  'Wilhelm Friedemann': 0.078125,
#  'Philipp Telemann': 0.015625,
#  'Johann Gottlieb Görner': 0.015625,
#  'Görner': 0.015625,
#  'Nicolas': 0.015625,
#  'Paul Wagner': 0.015625,
#  'Anna Magdalena': 0.03125,
#  'Johann Heinrich Ernesti': 0.015625,
#  'Johann Matthias Gesner': 0.015625,
#  'Vereinigte Zwietracht': 0.015625,
#  'Müller': 0.015625,
#  'another Bach Cantata': 0.015625,
#  'Maria Amalia': 0.03125,
#  'Charles of Sicily': 0.03125,
#  'Charles III': 0.03125,
#  'Johann Christian Hoffmann': 0.03125,
#  'Marianne von Ziegler': 0.03125,
#  'J. C. Gottsched': 0.03125,
#  'Johann Abraham Birnbaum': 0.03125,
#  'Peters': 0.03125,
#  'Elias Gottlieb Haussmann': 0.03125,
#  'Fritz Volbach': 0.03125,
#  'Haussmann': 0.046875,
#  'Regine Susanna': 0.03125,
#  'Beethoven': 0.015625,
#  "Johann Christoph Friedrich's": 0.03125,
#  'Sebastian Bach': 0.046875,
#  'Vivaldi': 0.015625,
#  'Frescobaldi': 0.015625,
#  'Kerl': 0.03125,
#  'Fischer': 0.03125,
#  'Herein Bach': 0.015625,
#  'Reinhard Keiser': 0.03125,
#  'Handel': 0.046875,
#  'Fritz': 0.015625,
#  'Alto': 0.015625,
#  'Wahre Grundsätze': 0.015625,
#  'Brunswick': 0.03125,
#  'Hasse': 0.046875,
#  'Friedemann': 0.015625,
#  'Duke Ernst': 0.015625,
#  'Duke Christian of Weissenfels': 0.03125,
#  'Vom Himmel': 0.015625,
#  'Christopher Weigel': 0.015625,
#  'Johann G. Schübler': 0.03125,
#  'Count Kaiserling': 0.015625,
#  'Frederick II': 0.015625}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
degree_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Centralityで上位の人たちは誰？
#
# Johann Christoph は Johann Sebastien の一番年上の兄。
#
# ```
# In 1695, when Johann Sebastian was not quite ten years old, his father
# died. He lost his mother at an earlier period.(47) So, being left an
# orphan, he became dependent on his eldest brother, Johann Christoph,
# Organist at Ohrdruf,(48) from whom he received his earliest lessons on the
# Clavier.(49)
# ```
#
# Wilhelm Friedemann は Johann Sebastien の１番年上の子供。
# ```
# Bach and his eldest son, Wilhelm Friedemann.
# ```
#
# Carl Philipp Emmanuel は Johann Sebastien の２番目に年上の子供。
# ```
# His two eldest sons, Wilhelm Friedemann and Carl Philipp Emmanuel, were his most
# distinguished pupils, not because he gave them better instruction than the
# rest, but because from their earliest youth they were brought up amid good
# music at home.
# ```

# %%
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
betweenness_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %%
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
closeness_df.sort_values('centrality', ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: >
