# %% [markdown]
# # ポジティブ＆ネガティブ分析
#
# Date: 2023/11/10, 2023/11/15, 2023/12/3

# %% [markdown]
# ## ChatGPTへ質問 日本語版

# %% [markdown]
# ### ポジティブ＆ネガティブ
#
# あなたはショールームの見学者で、見学後の感想をアンケートへ書くところです。見学者としてのポジティブかつネガティブな表現を混ぜた感想を適当に30個作成してください。各感想を長文で述べてください。Pythonのリスト形式で出力してください。

# %%
positive_negative = [
    "ショールームの清潔さには好感が持てましたが、一部の展示品が傷んでいるのが気になりました。",
    "スタッフの丁寧な対応がありましたが、商品の説明が少なく、理解しにくかったです。",
    "展示品の品質は高く、特にデザインに魅了されましたが、価格が高すぎると感じました。",
    "ショールームの広さとレイアウトは素晴らしかったが、一部のエリアが混雑していました。",
    "商品のバリエーションが豊富で、選択肢が多い一方で、一部のカテゴリーが不足していました。",
    "インテリアデザインがモダンで印象的でしたが、一部のエリアが古く感じられました。",
    "スタッフの対応は親切で好感が持てましたが、混雑しておりゆっくり見学できませんでした。",
    "展示品のディスプレイは美しく、高い品質が感じられましたが、価格が高すぎると感じました。",
    "ショールーム内の照明が良好で、商品が見やすかったが、一部のエリアが薄暗かったです。",
    "商品の価格設定が適切で良心的でしたが、スタッフの知識が不足しているように感じました。",
    "展示品の配置が工夫され、テーマ性がありましたが、一部の商品が見つけにくかったです。",
    "ショールーム内の案内が分かりやすく、スタッフの対応も良かったが、混雑が気になりました。",
    "商品の新しさとデザインに魅了されましたが、スタッフの態度が冷淡で残念でした。",
    "ショールームの雰囲気が明るく、居心地が良かったが、一部の商品が陳腐に感じられました。",
    "展示品の保守状態が良好で、商品の信頼性に安心感を覚えましたが、価格が心配です。",
    "ショールームの配置が効果的で見やすかったが、スタッフの忙しさが対応に影響していました。",
    "スタッフの知識が豊富で的確でしたが、商品の新しさに欠け、刷新が必要かもしれません。",
    "商品の魅力が引き立つディスプレイでしたが、スタッフの説明が簡略化されていた印象です。",
    "ショールーム内の音楽が心地よく、雰囲気が良かったが、一部エリアが騒がしかったです。",
    "展示品のデザインが洗練されており、一部の商品には本当に惹かれましたが、価格が心配です。",
    "ショールームの温度が快適で、滞在が楽しかったが、一部のエリアが寒かったです。",
    "商品の新しさが感じられ、デザインが魅力的でしたが、スタッフの態度が気になりました。",
    "ショールーム内のサインが分かりやすく、効果的でしたが、一部エリアの表示が不足していました。",
    "スタッフの態度が温暖で、親しみやすかったが、商品の一部が古びて見えました。",
    "展示品の配置が程よく、見学がスムーズでしたが、一部の商品が埋もれているようでした。",
    "ショールーム内の照明が美しく、商品が引き立っていましたが、一部の商品が高価でした。",
    "展示されている商品が洗練されており、一部の商品には本当に魅了されましたが、価格が気になります。",
    "ショールーム全体の雰囲気が素晴らしく、多様な商品が揃っていたが、価格が手の届かないものもありました。"
]

len(positive_negative)
# Out:
# 28

# %% [markdown]
# ### ポジティブ
#
# あなたはショールームの見学者で、見学後の感想をアンケートへ書くところです。見学者としてのポジティブな感想を適当に30個作成してください。各感想を長文で述べてください。Pythonのリスト形式で出力してください。

# %%
positive = [
    "ショールームの清潔感に一同感激しました。全体的に整理されており、商品が魅力的に展示されていました。",
    "スタッフの方々の丁寧で親しみやすい対応が印象的でした。質問にも親身に答えていただき、ありがたかったです。",
    "展示品の品質が非常に高く、デザインにもこだわりを感じました。新しいアイデアやトレンドを発見できました。",
    "ショールームの広さと効果的なレイアウトに感心しました。各エリアがテーマ性を持ち、見学が楽しいものとなりました。",
    "商品の多様性に驚きました。さまざまなスタイルや用途の商品が揃っており、自分のニーズに合ったものが見つかりました。",
    "ショールームのインテリアデザインが素晴らしく、訪れるだけで気分が上がりました。商品との調和が感じられました。",
    "スタッフの方々が専門的で豊富な知識を持っていました。商品に関する質問に対しても理解が深く、安心感がありました。",
    "展示品のディスプレイが美しく、細部までこだわりが感じられました。商品の魅力が引き立っていました。",
    "ショールーム内の照明が適切で、商品がより魅力的に見えました。各商品の特長が明確に浮き彫りにされていました。",
    "商品の価格設定が合理的で、購買しやすい価格帯が多かったです。コストパフォーマンスが良いと感じました。",
    "ショールーム内の音楽が心地よく、ゆったりとした雰囲気が演出されていました。見学がより楽しいものとなりました。",
    "展示品の配置が効果的で、テーマ性がありました。各エリアが異なるコンセプトを持ち、見学が飽きませんでした。",
    "ショールーム内での案内が分かりやすく、道迷いすることなくスムーズに見学できました。効率的な見学ができました。",
    "商品の新しさとトレンド感が際立ちました。最新のデザインや機能が取り入れられていて、驚くばかりでした。",
    "ショールームの雰囲気が穏やかで、リラックスできる空間でした。商品をじっくりと見学でき、ゆったりと過ごせました。",
    "展示品の保守状態が良好で、商品に対する信頼感がありました。品質の高さが一貫していました。",
    "ショールーム内の照明が柔らかく、心地よい雰囲気を醸し出していました。商品がより魅力的に見えました。",
    "商品の新しさが感じられ、デザインが洗練されていました。先進的なアプローチが取り入れられていて感動しました。",
    "ショールーム内のサインや表示が分かりやすく、目的地に迷わずに到達できました。利便性が高かったです。",
    "スタッフの方々が笑顔で迎えてくれ、親しみやすい雰囲気がありました。気軽に質問でき、好感が持てました。",
    "展示品のデザインがユニークであり、個性的なアプローチが感じられました。新しい視点を得ることができました。",
    "ショールームの温度や空調が快適でした。見学中も過ごしやすく、商品に集中できました。",
    "商品の陳列が工夫されており、各商品が際立っていました。バラエティ豊かで見ていて飽きませんでした。",
    "ショールーム内の雰囲気が活気に満ち、賑やかで楽しい雰囲気でした。商品との一体感がありました。",
    "展示品の配置が見やすく、商品の流れが自然でした。見学がストレスなく進められました。",
    "ショールーム全体がクリエイティブな雰囲気に包まれていました。商品だけでなく、空間自体がインスピレーションを与えてくれました。",
    "スタッフの方々が柔軟かつ迅速に対応してくれました。要望や質問に対して素早く対応していただき、感謝しています。",
    "展示品のデザインや機能性に感動しました。普段は気づかないような細部のこだわりが素晴らしかったです。",
    "ショールーム内の各エリアが異なるコンセプトで統一され、見学が飽きることがありませんでした。"
]

len(positive)
# Out:
# 29

# %% [markdown]
# ### ネガティブ
#
# あなたはショールームの見学者で、見学後の感想をアンケートへ書くところです。見学者としてのネガティブな表現を混ぜた感想を適当に30個作成してください。各感想を長文で述べてください。Pythonのリスト形式で出力してください。

# %%
negative = [
    "ショールームの清潔さに不満がありました。一部でゴミやほこりが見受けられ、印象が悪かったです。",
    "スタッフの方々の対応が冷淡で、質問にも十分な回答が得られませんでした。もう少し親しみやすい態度が期待されます。",
    "展示品の品質が低く、一部で傷や不具合が見受けられました。商品の信頼性に疑念を抱きました。",
    "ショールーム内のレイアウトが不規則で混雑しており、ゆっくりと商品を見ることが難しかったです。",
    "商品のバリエーションが限られており、選択肢が少なかったです。もっと多様性が欲しかったです。",
    "インテリアデザインが古臭く感じられました。モダンな雰囲気が漂っておらず、期待外れでした。",
    "スタッフの方々が無視するような態度を見受けました。質問に対して十分な情報提供がなされませんでした。",
    "展示品のディスプレイが見づらく、商品の特徴が伝わりにくかったです。もっと効果的な陳列が求められます。",
    "ショールーム内の照明が暗すぎて、商品がよく見えませんでした。もっと明るい照明が必要でした。",
    "商品の価格設定が高過ぎて、コストパフォーマンスが合わないと感じました。もっと手頃な価格帯が欲しかったです。",
    "ショールーム内での音楽が不快で、ゆっくりとした雰囲気を楽しむことができませんでした。",
    "展示品の配置が混雑しており、商品が埋もれて見えました。もっと広いスペースが必要でした。",
    "ショールーム内での案内が不親切で、目的地までのルートが分かりにくかったです。もっと分かりやすい案内が欲しかったです。",
    "商品の新しさやデザインに欠け、時代遅れの印象を受けました。もっと先進的な商品が期待されます。",
    "ショールームの雰囲気が冷たく、居心地が悪かったです。もっと温かみのある空間が求められました。",
    "展示品の保守状態が悪く、一部で傷や汚れが目立ちました。商品のクオリティに疑念が残りました。",
    "ショールーム内の照明がまばらで、商品が十分に映えませんでした。もっと均等な照明が必要でした。",
    "商品の新しさや革新性が感じられず、既視感のあるデザインが多かったです。もっと斬新なアプローチが期待されます。",
    "ショールーム内のサインが不足しており、目的地までの道が分からず迷いました。もっと分かりやすい案内が必要でした。",
    "スタッフの態度が無愛想で、購買意欲を削がれました。もっと親しみやすい態度が期待されます。",
    "展示品のデザインが単調で、個性やユニークさが欠けました。もっと斬新な発想が求められます。",
    "ショールーム内の温度が高く、滞在が不快でした。もっと快適な環境が期待されます。",
    "商品の陳列が乱雑で、商品が見づらかったです。もっと整理された陳列が望まれます。",
    "ショールーム内の照明が眩しく、商品が過剰に強調されました。もっと柔らかい照明が良かったです。",
    "展示品のデザインが平凡で、他と差別化が図られていないように感じました。もっと個性的な商品が欲しかったです。",
    "ショールーム内の雰囲気が静かで、賑やかさが欠けました。もっと活気ある雰囲気が期待されます。",
    "スタッフの方々が混雑に忙殺され、質問に応じる余裕がなかったです。もっと効率的なスタッフ配置が必要でした。",
    "展示品のデザインや機能に驚きがなく、期待値を下回る印象を受けました。もっと斬新な商品が欲しかったです。"
]

len(negative)
# Out:
# 28

# %%
import copy
imp = copy.copy(positive_negative)
imp.extend(positive)
imp.extend(negative)
imp
# Out:
# ['ショールームの清潔さには好感が持てましたが、一部の展示品が傷んでいるのが気になりました。',
#  'スタッフの丁寧な対応がありましたが、商品の説明が少なく、理解しにくかったです。',
#  '展示品の品質は高く、特にデザインに魅了されましたが、価格が高すぎると感じました。',
#  'ショールームの広さとレイアウトは素晴らしかったが、一部のエリアが混雑していました。',
#  '商品のバリエーションが豊富で、選択肢が多い一方で、一部のカテゴリーが不足していました。',
#  'インテリアデザインがモダンで印象的でしたが、一部のエリアが古く感じられました。',
#  'スタッフの対応は親切で好感が持てましたが、混雑しておりゆっくり見学できませんでした。',
#  '展示品のディスプレイは美しく、高い品質が感じられましたが、価格が高すぎると感じました。',
#  'ショールーム内の照明が良好で、商品が見やすかったが、一部のエリアが薄暗かったです。',
#  '商品の価格設定が適切で良心的でしたが、スタッフの知識が不足しているように感じました。',
#  '展示品の配置が工夫され、テーマ性がありましたが、一部の商品が見つけにくかったです。',
#  'ショールーム内の案内が分かりやすく、スタッフの対応も良かったが、混雑が気になりました。',
#  '商品の新しさとデザインに魅了されましたが、スタッフの態度が冷淡で残念でした。',
#  'ショールームの雰囲気が明るく、居心地が良かったが、一部の商品が陳腐に感じられました。',
#  '展示品の保守状態が良好で、商品の信頼性に安心感を覚えましたが、価格が心配です。',
#  'ショールームの配置が効果的で見やすかったが、スタッフの忙しさが対応に影響していました。',
#  'スタッフの知識が豊富で的確でしたが、商品の新しさに欠け、刷新が必要かもしれません。',
#  '商品の魅力が引き立つディスプレイでしたが、スタッフの説明が簡略化されていた印象です。',
#  'ショールーム内の音楽が心地よく、雰囲気が良かったが、一部エリアが騒がしかったです。',
#  '展示品のデザインが洗練されており、一部の商品には本当に惹かれましたが、価格が心配です。',
# ...

# %%
len(imp)
# Out:
# 85

# %%
import random
random.shuffle(imp)
imp
# Out:
# ['ショールーム内の雰囲気が静かで、賑やかさが欠けました。もっと活気ある雰囲気が期待されます。',
#  '商品の陳列が工夫されており、各商品が際立っていました。バラエティ豊かで見ていて飽きませんでした。',
#  '商品の陳列が乱雑で、商品が見づらかったです。もっと整理された陳列が望まれます。',
#  '展示品の配置が程よく、見学がスムーズでしたが、一部の商品が埋もれているようでした。',
#  '商品の価格設定が適切で良心的でしたが、スタッフの知識が不足しているように感じました。',
#  'ショールームの清潔さには好感が持てましたが、一部の展示品が傷んでいるのが気になりました。',
#  'インテリアデザインがモダンで印象的でしたが、一部のエリアが古く感じられました。',
#  'ショールームの雰囲気が穏やかで、リラックスできる空間でした。商品をじっくりと見学でき、ゆったりと過ごせました。',
#  '商品の新しさやデザインに欠け、時代遅れの印象を受けました。もっと先進的な商品が期待されます。',
#  '商品の価格設定が合理的で、購買しやすい価格帯が多かったです。コストパフォーマンスが良いと感じました。',
#  'ショールームの広さとレイアウトは素晴らしかったが、一部のエリアが混雑していました。',
#  '展示品のデザインや機能に驚きがなく、期待値を下回る印象を受けました。もっと斬新な商品が欲しかったです。',
#  'ショールームの温度や空調が快適でした。見学中も過ごしやすく、商品に集中できました。',
#  '展示品のディスプレイが美しく、細部までこだわりが感じられました。商品の魅力が引き立っていました。',
#  'ショールーム内のサインが不足しており、目的地までの道が分からず迷いました。もっと分かりやすい案内が必要でした。',
#  'ショールーム内の照明が良好で、商品が見やすかったが、一部のエリアが薄暗かったです。',
#  '展示品のデザインが洗練されており、一部の商品には本当に惹かれましたが、価格が心配です。',
#  'ショールーム内の各エリアが異なるコンセプトで統一され、見学が飽きることがありませんでした。',
#  'ショールーム内の照明が眩しく、商品が過剰に強調されました。もっと柔らかい照明が良かったです。',
# ...

# %% [markdown]
# ## ChatGPTへ質問：分類＝＝＞ChatGPTは以下のプロンプトではエラーを起こし処理できず
#
# 次のPythonリストデータを、ポジティブな表現のみを含むもの、ネガティブな表現のみを含むもの、ポジティブおよびネガティブな表現を含むもので分類してください。分類結果をPythonの辞書形式で出力してください。

# %% [markdown]
# ChatGPTがプロンプトの意味をうまく解釈できず混乱してしまった？従来手法で分類すべきとの結論になった。

# %% [markdown]
# 次のPythonリストデータについて、ポジティブな表現のみを含むもの、ネガティブな表現のみを含むもの、ポジティブおよびネガティブな表現を含むものに分類するための Pythonコードを生成してください。

# %% [markdown]
# ## 他の日本語向け自然言語処理に向けデータ出力

# %%
data = {
    'positive': positive,
    'negative': negative,
    'positive_negative': positive_negative,
    'random': imp
}

import yaml
with open("../data/impressions.yaml", 'w') as f:
    yaml.dump(data, f)

# %%
with open("../data/impressions.yaml", 'r') as f:
    print(yaml.safe_load(f))
# Out:
# {'negative': ['ショールームの清潔さに不満がありました。一部でゴミやほこりが見受けられ、印象が悪かったです。', 'スタッフの方々の対応が冷淡で、質問にも十分な回答が得られませんでした。もう少し親しみやすい態度が期待されます。', '展示品の品質が低く、一部で傷や不具合が見受けられました。商品の信頼性に疑念を抱きました。', 'ショールーム内のレイアウトが不規則で混雑しており、ゆっくりと商品を見ることが難しかったです。', '商品のバリエーションが限られており、選択肢が少なかったです。もっと多様性が欲しかったです。', 'インテリアデザインが古臭く感じられました。モダンな雰囲気が漂っておらず、期待外れでした。', 'スタッフの方々が無視するような態度を見受けました。質問に対して十分な情報提供がなされませんでした。', '展示品のディスプレイが見づらく、商品の特徴が伝わりにくかったです。もっと効果的な陳列が求められます。', 'ショールーム内の照明が暗すぎて、商品がよく見えませんでした。もっと明るい照明が必要でした。', '商品の価格設定が高過ぎて、コストパフォーマンスが合わないと感じました。もっと手頃な価格帯が欲しかったです。', 'ショールーム内での音楽が不快で、ゆっくりとした雰囲気を
11. "I admired the showroom's dedication to minimalism. The simplicity of the designs created a sense of calm and sophistication."
12. "The showroom's artistic displays were a visual delight. The creativity showcased in each exhibit added a unique and enjoyable touch."
13. "The showroom's friendly and knowledgeable staff made the visit exceptional. Their passion for the products was evident and contagious."
14. "I was captivated by the showroom's thematic displays. The creative approach added an extra layer of excitement and interest."
15. "The showroom's use of cutting-edge technology was impressive. Interactive exhibits provided a fun and immersive experience."
16. "I enjoyed the showroom's sleek and modern designs. The contemporary aesthetic added a touch of sophistication to every display."
17. "The showroom's commitment to innovation was evident in every product. It felt like a glimpse into the future of design and technology."
18. "I appreciated the showroom's emphasis on sustainability. Eco-friendly materials and practices showcased a commendable commitment to the environment."
19. "The showroom's well-organized layout made it a pleasure to navigate. It was easy to explore and appreciate each exhibit."
20. "I loved the showroom's diverse range of products. The variety allowed for a comprehensive view of different styles and preferences."
21. "The showroom's use of natural lighting created a warm and inviting atmosphere. It enhanced the beauty of the designs on display."
22. "I was fascinated by the showroom's dedication to craftsmanship. Each piece demonstrated a level of skill and artistry that was truly commendable."
23. "The showroom's commitment to customer service was outstanding. The staff's helpfulness and friendliness enhanced the overall experience."
24. "I appreciated the showroom's focus on functionality. The practical designs showcased how aesthetics can also serve a purpose."
25. "The showroom's interactive exhibits were not only entertaining but also educational. It made the visit both enjoyable and informative."
26. "I was impressed by the showroom's commitment to quality. Each product exuded a sense of durability and excellence in design."
27. "The showroom's use of technology to enhance the customer experience was innovative. It added a modern and dynamic touch to the visit."
28. "The showroom's dedication to creating a welcoming environment was evident. It felt like a space where everyone could find something they loved."
29. "I admired the showroom's focus on creating a unique and memorable experience. It went beyond showcasing products and told a story."
30. "The showroom's commitment to staying on trend was noticeable. It felt like a forward-thinking space that reflects the latest in design and style."'''

positive = re.sub(r'\d+\.\s|\"', '', text).split('\n')
len(positive)
# Out:
# 30

# %% [markdown]
# ### ネガティブ
#
# 以下を30回繰り返し実行して、それぞれの結果を出力してください。
#
# あなたはショールームの見学者で、見学後のネガティブな感想を英語で30個述べてください。

# %%
text = '''1. "The showroom's cluttered layout made it difficult to navigate, creating a frustrating experience."
2. "Despite the showroom's modern theme, the lack of updated products left it feeling outdated and unimpressive."
3. "The staff's lack of knowledge about the products was disappointing and hindered the overall experience."
4. "The showroom's dim lighting made it challenging to properly examine and appreciate the showcased items."
5. "I found the showroom's overuse of bold colors and patterns overwhelming and headache-inducing."
6. "The lack of air conditioning in the showroom made the entire visit uncomfortable and unpleasant."
7. "The showroom's disorganized displays and lack of proper signage made it confusing and frustrating to find specific items."
8. "The unpleasant odor in the showroom was a major turnoff, overshadowing any positive aspects."
9. "The showroom's limited product variety failed to meet expectations, resulting in a lackluster experience."
10. "The showroom's constant background noise, including loud music, made it difficult to focus and communicate with staff."
11. "I was disappointed by the showroom's poor maintenance; several exhibits were visibly worn and damaged."
12. "The showroom's high prices were not justified by the quality of the products, leaving me feeling ripped off."
13. "The unprofessional behavior of some staff members negatively impacted the overall impression of the showroom."
14. "The lack of proper ventilation in the showroom made it feel stuffy and uncomfortable."
15. "The showroom's inadequate customer service, with rude and unhelpful staff, made the visit unpleasant."
16. "Despite the showroom's advertised discounts, the final prices were still unreasonably high."
17. "The showroom's outdated and malfunctioning interactive displays were a major disappointment."
18. "The lack of available seating made it impossible to take a break and rest during the visit."
19. "The showroom's misleading advertising created false expectations, leading to disappointment upon arrival."
20. "The showroom's poor layout and congested spaces made it difficult to move around freely."
21. "The showroom's misleading product descriptions resulted in a mismatch between expectations and reality."
22. "The showroom's subpar cleanliness standards, including dirty floors and dusty displays, were off-putting."
23. "The lack of accessibility features in the showroom posed challenges for individuals with disabilities."
24. "The showroom's unresponsive and indifferent staff failed to address customer concerns."
25. "The absence of clear pricing information for displayed items created uncertainty and frustration."
26. "The showroom's inconvenient location and lack of parking options added unnecessary stress to the visit."
27. "The showroom's outdated and malfunctioning technology diminished the overall experience."
28. "The showroom's cramped and crowded spaces made it difficult to browse comfortably."
29. "The showroom's lack of restroom facilities or clear directions to them made the visit inconvenient."
30. "The showroom's overall lack of innovation and creativity left me unimpressed and dissatisfied."'''

negative = re.sub(r'\d+\.\s|\"', '', text).split('\n')
len(negative)
# Out:
# 30

# %%
import copy
imp = copy.copy(positive_negative)
imp.extend(positive)
imp.extend(negative)
imp
# Out:
# ['The showroom was absolutely stunning! The modern designs and vibrant colors were impressive. However, the lack of natural lighting made some areas feel a bit dim.',
#  'I was amazed by the innovative features in the showroom. The interactive displays were engaging, but the crowded layout made navigation a bit challenging.',
#  "The showroom's minimalist approach was refreshing. The sleek designs and clean lines were appealing. However, the limited seating options were a drawback.",
#  'I loved the variety of products in the showroom. The knowledgeable staff provided great insights. On the downside, the high prices were a bit discouraging.',
#  "The showroom's unique theme caught my attention. The creative displays were captivating, but the loud background music made it hard to focus on product details.",
#  "The showroom's spacious layout allowed for easy exploration. The friendly staff added to the positive experience. However, the outdated decor was a minor letdown.",
# ...

# %%
import random
random.shuffle(imp)
imp
# Out:
# ["The showroom's high prices were not justified by the quality of the products, leaving me feeling ripped off.",
#  "I loved the showroom's diverse range of products. The variety allowed for a comprehensive view of different styles and preferences.",
#  "The showroom's commitment to innovation was evident in every product. The helpful staff made the visit enjoyable. On the downside, the lack of a cafe or refreshment area was a missed opportunity.",
#  'The lack of available seating made it impossible to take a break and rest during the visit.',
#  "I was disappointed by the showroom's poor maintenance; several exhibits were visibly worn and damaged.",
#  "The showroom's commitment to staying on trend was noticeable. It felt like a forward-thinking space that reflects the latest in design and style.",
#  "The showroom's friendly staff made the visit memorable. Their knowledge and enthusiasm added to the positive atmosphere.",
# ...

# %%
data = {
    'positive': positive,
    'negative': negative,
    'positive_negative': positive_negative,
    'random': imp
}

import yaml
with open("../data/impressions_en.yaml", 'w') as f:
    yaml.dump(data, f)
